# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction:-Bacterial-competition,-warming-and-size" data-toc-modified-id="Introduction:-Bacterial-competition,-warming-and-size-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction: Bacterial competition, warming and size</a></span></li><li><span><a href="#The-Model" data-toc-modified-id="The-Model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>The Model</a></span><ul class="toc-item"><li><span><a href="#Adaptation-of-Marsland" data-toc-modified-id="Adaptation-of-Marsland-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Adaptation of Marsland</a></span><ul class="toc-item"><li><span><a href="#Consumers" data-toc-modified-id="Consumers-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Consumers</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Resources</a></span></li><li><span><a href="#Constraints" data-toc-modified-id="Constraints-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Constraints</a></span></li></ul></li><li><span><a href="#Updated---Adaptation-of-Marsland-and-Pacciani" data-toc-modified-id="Updated---Adaptation-of-Marsland-and-Pacciani-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Updated - Adaptation of Marsland and Pacciani</a></span><ul class="toc-item"><li><span><a href="#Consumers" data-toc-modified-id="Consumers-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Consumers</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Resources</a></span></li><li><span><a href="#Constraints" data-toc-modified-id="Constraints-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Constraints</a></span></li></ul></li><li><span><a href="#Type-I-and-Type-II-functional-responses" data-toc-modified-id="Type-I-and-Type-II-functional-responses-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Type I and Type II functional responses</a></span><ul class="toc-item"><li><span><a href="#Type-I" data-toc-modified-id="Type-I-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Type I</a></span></li><li><span><a href="#Type-II" data-toc-modified-id="Type-II-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Type II</a></span></li><li><span><a href="#Constraints" data-toc-modified-id="Constraints-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Constraints</a></span></li></ul></li><li><span><a href="#Comparison-to-the-Marsland-model" data-toc-modified-id="Comparison-to-the-Marsland-model-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Comparison to the Marsland model</a></span><ul class="toc-item"><li><span><a href="#The-Marsland-model" data-toc-modified-id="The-Marsland-model-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>The Marsland model</a></span></li><li><span><a href="#Differences-between-ours-and-Marslands-model" data-toc-modified-id="Differences-between-ours-and-Marslands-model-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Differences between ours and Marslands model</a></span></li></ul></li></ul></li><li><span><a href="#2-species-2-resources-model" data-toc-modified-id="2-species-2-resources-model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>2-species 2-resources model</a></span><ul class="toc-item"><li><span><a href="#Bacteria" data-toc-modified-id="Bacteria-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Bacteria</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Resources</a></span></li></ul></li><li><span><a href="#Modelling-functional-traits" data-toc-modified-id="Modelling-functional-traits-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Modelling functional traits</a></span><ul class="toc-item"><li><span><a href="#Temperature-and-size-dependance" data-toc-modified-id="Temperature-and-size-dependance-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Temperature and size dependance</a></span></li></ul></li><li><span><a href="#Running-the-model" data-toc-modified-id="Running-the-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Running the model</a></span></li><li><span><a href="#Equilibria-solutions" data-toc-modified-id="Equilibria-solutions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Equilibria solutions</a></span><ul class="toc-item"><li><span><a href="#No-competition-for-resources" data-toc-modified-id="No-competition-for-resources-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>No competition for resources</a></span><ul class="toc-item"><li><span><a href="#Phase-plane-(resource-vs.-bacteria)" data-toc-modified-id="Phase-plane-(resource-vs.-bacteria)-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Phase plane (resource vs. bacteria)</a></span></li><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 = C2)</a></span></li><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 != C2)</a></span></li></ul></li><li><span><a href="#Competition-for-resources" data-toc-modified-id="Competition-for-resources-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Competition for resources</a></span><ul class="toc-item"><li><span><a href="#Type-I-functional-response" data-toc-modified-id="Type-I-functional-response-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Type I functional response</a></span></li><li><span><a href="#Type-II-functional-response" data-toc-modified-id="Type-II-functional-response-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Type II functional response</a></span></li><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 != C2)</a></span></li><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 = C2)</a></span></li></ul></li><li><span><a href="#Co-existence-under-competition-for-resources" data-toc-modified-id="Co-existence-under-competition-for-resources-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Co-existence under competition for resources</a></span><ul class="toc-item"><li><span><a href="#Phase-plane-analysis" data-toc-modified-id="Phase-plane-analysis-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Phase plane analysis</a></span></li></ul></li><li><span><a href="#Investigating-all-solutions" data-toc-modified-id="Investigating-all-solutions-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Investigating all solutions</a></span></li></ul></li><li><span><a href="#3-species-1-resource-system" data-toc-modified-id="3-species-1-resource-system-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>3-species 1-resource system</a></span></li><li><span><a href="#Time-to-equilibrium" data-toc-modified-id="Time-to-equilibrium-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Time to equilibrium</a></span><ul class="toc-item"><li><span><a href="#2-species-system,-long-simulation-time" data-toc-modified-id="2-species-system,-long-simulation-time-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>2-species system, long simulation time</a></span></li><li><span><a href="#2---5-species-system,-2-different-functional-groups" data-toc-modified-id="2---5-species-system,-2-different-functional-groups-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>2 - 5 species system, 2 different functional groups</a></span><ul class="toc-item"><li><span><a href="#Type-I" data-toc-modified-id="Type-I-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Type I</a></span><ul class="toc-item"><li><span><a href="#Code" data-toc-modified-id="Code-8.2.1.1"><span class="toc-item-num">8.2.1.1&nbsp;&nbsp;</span>Code</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-8.2.1.2"><span class="toc-item-num">8.2.1.2&nbsp;&nbsp;</span>Plots</a></span></li></ul></li><li><span><a href="#Type-II" data-toc-modified-id="Type-II-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Type II</a></span><ul class="toc-item"><li><span><a href="#Code" data-toc-modified-id="Code-8.2.2.1"><span class="toc-item-num">8.2.2.1&nbsp;&nbsp;</span>Code</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-8.2.2.2"><span class="toc-item-num">8.2.2.2&nbsp;&nbsp;</span>Plots</a></span></li></ul></li></ul></li><li><span><a href="#2---5-species-system,-2-5-different-functional-groups" data-toc-modified-id="2---5-species-system,-2-5-different-functional-groups-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>2 - 5 species system, 2-5 different functional groups</a></span><ul class="toc-item"><li><span><a href="#Plots" data-toc-modified-id="Plots-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Plots</a></span></li></ul></li><li><span><a href="#Non-dimensionalisation" data-toc-modified-id="Non-dimensionalisation-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Non-dimensionalisation</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#Summary-to-this-point" data-toc-modified-id="Summary-to-this-point-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Summary to this point</a></span></li><li><span><a href="#Next-steps" data-toc-modified-id="Next-steps-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Next steps</a></span></li></ul></li><li><span><a href="#Plan" data-toc-modified-id="Plan-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Plan</a></span><ul class="toc-item"><li><span><a href="#Model-simulations" data-toc-modified-id="Model-simulations-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Model simulations</a></span><ul class="toc-item"><li><span><a href="#Look-at-time-to-equilibrium-(i.e.-one-goes-extinct)" data-toc-modified-id="Look-at-time-to-equilibrium-(i.e.-one-goes-extinct)-10.1.1"><span class="toc-item-num">10.1.1&nbsp;&nbsp;</span>Look at time to equilibrium (i.e. one goes extinct)</a></span></li><li><span><a href="#Temperature/metabolism" data-toc-modified-id="Temperature/metabolism-10.1.2"><span class="toc-item-num">10.1.2&nbsp;&nbsp;</span>Temperature/metabolism</a></span></li></ul></li><li><span><a href="#Plan-for-potential-paper" data-toc-modified-id="Plan-for-potential-paper-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Plan for potential paper</a></span></li><li><span><a href="#Future-paper" data-toc-modified-id="Future-paper-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Future paper</a></span></li></ul></li><li><span><a href="#Analysing-the-model" data-toc-modified-id="Analysing-the-model-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Analysing the model</a></span><ul class="toc-item"><li><span><a href="#Incorporating-temperature" data-toc-modified-id="Incorporating-temperature-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Incorporating temperature</a></span></li><li><span><a href="#Find-all-possible-equilibria-Bacteria-masses-at-different-Ea-values" data-toc-modified-id="Find-all-possible-equilibria-Bacteria-masses-at-different-Ea-values-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Find all possible equilibria Bacteria masses at different Ea values</a></span></li><li><span><a href="#Expressing-size-dependancy" data-toc-modified-id="Expressing-size-dependancy-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Expressing size dependancy</a></span></li></ul></li><li><span><a href="#Context-and-possible-aim" data-toc-modified-id="Context-and-possible-aim-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Context and possible aim</a></span><ul class="toc-item"><li><span><a href="#Aim" data-toc-modified-id="Aim-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Aim</a></span><ul class="toc-item"><li><span><a href="#Model-simulations" data-toc-modified-id="Model-simulations-12.1.1"><span class="toc-item-num">12.1.1&nbsp;&nbsp;</span>Model simulations</a></span><ul class="toc-item"><li><span><a href="#Conclusions-of-model-simulation-equlibria" data-toc-modified-id="Conclusions-of-model-simulation-equlibria-12.1.1.1"><span class="toc-item-num">12.1.1.1&nbsp;&nbsp;</span>Conclusions of model simulation equlibria</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction:-Bacterial-competition,-warming-and-size" data-toc-modified-id="Introduction:-Bacterial-competition,-warming-and-size-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction: Bacterial competition, warming and size</a></span></li><li><span><a href="#The-Model" data-toc-modified-id="The-Model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>The Model</a></span><ul class="toc-item"><li><span><a href="#Set-up" data-toc-modified-id="Set-up-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Set up</a></span><ul class="toc-item"><li><span><a href="#Consumers" data-toc-modified-id="Consumers-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Consumers</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Resources</a></span></li></ul></li><li><span><a href="#Constraints" data-toc-modified-id="Constraints-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Constraints</a></span></li><li><span><a href="#Comparison-to-the-Marsland-model" data-toc-modified-id="Comparison-to-the-Marsland-model-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Comparison to the Marsland model</a></span><ul class="toc-item"><li><span><a href="#The-Marsland-model" data-toc-modified-id="The-Marsland-model-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>The Marsland model</a></span></li><li><span><a href="#Differences-between-ours-and-Marslands-model" data-toc-modified-id="Differences-between-ours-and-Marslands-model-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Differences between ours and Marslands model</a></span></li></ul></li></ul></li><li><span><a href="#2-species-2-resources-model" data-toc-modified-id="2-species-2-resources-model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>2-species 2-resources model</a></span><ul class="toc-item"><li><span><a href="#Bacteria" data-toc-modified-id="Bacteria-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Bacteria</a></span></li><li><span><a href="#Resources" data-toc-modified-id="Resources-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Resources</a></span></li></ul></li><li><span><a href="#Modelling-functional-traits" data-toc-modified-id="Modelling-functional-traits-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Modelling functional traits</a></span><ul class="toc-item"><li><span><a href="#Temperature-and-size-dependance" data-toc-modified-id="Temperature-and-size-dependance-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Temperature and size dependance</a></span></li></ul></li><li><span><a href="#Running-the-model" data-toc-modified-id="Running-the-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Running the model</a></span></li><li><span><a href="#Equilibria-solutions" data-toc-modified-id="Equilibria-solutions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Equilibria solutions</a></span><ul class="toc-item"><li><span><a href="#No-competition-for-resources" data-toc-modified-id="No-competition-for-resources-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>No competition for resources</a></span><ul class="toc-item"><li><span><a href="#Phase-plane-(resource-vs.-bacteria)" data-toc-modified-id="Phase-plane-(resource-vs.-bacteria)-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Phase plane (resource vs. bacteria)</a></span></li><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 = C2)</a></span></li><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 != C2)</a></span></li></ul></li><li><span><a href="#Competition-for-resources" data-toc-modified-id="Competition-for-resources-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Competition for resources</a></span><ul class="toc-item"><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-!=-C2)-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 != C2)</a></span></li><li><span><a href="#Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)" data-toc-modified-id="Phase-plane-(bacteria-vs.-bacteria,-C1-=-C2)-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Phase plane (bacteria vs. bacteria, C1 = C2)</a></span></li></ul></li><li><span><a href="#Co-existence-under-competition-for-resources" data-toc-modified-id="Co-existence-under-competition-for-resources-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Co-existence under competition for resources</a></span><ul class="toc-item"><li><span><a href="#Phase-plane-analysis" data-toc-modified-id="Phase-plane-analysis-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Phase plane analysis</a></span></li><li><span><a href="#Time-to-equilibrium" data-toc-modified-id="Time-to-equilibrium-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Time to equilibrium</a></span></li></ul></li><li><span><a href="#Investigating-all-solutions" data-toc-modified-id="Investigating-all-solutions-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Investigating all solutions</a></span></li></ul></li><li><span><a href="#3-species-1-resource-system" data-toc-modified-id="3-species-1-resource-system-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>3-species 1-resource system</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#Summary-to-this-point" data-toc-modified-id="Summary-to-this-point-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Summary to this point</a></span></li><li><span><a href="#Next-steps" data-toc-modified-id="Next-steps-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Next steps</a></span></li></ul></li><li><span><a href="#Analysing-the-model" data-toc-modified-id="Analysing-the-model-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Analysing the model</a></span><ul class="toc-item"><li><span><a href="#Incorporating-temperature" data-toc-modified-id="Incorporating-temperature-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Incorporating temperature</a></span></li><li><span><a href="#Find-all-possible-equilibria-Bacteria-masses-at-different-Ea-values" data-toc-modified-id="Find-all-possible-equilibria-Bacteria-masses-at-different-Ea-values-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Find all possible equilibria Bacteria masses at different Ea values</a></span></li><li><span><a href="#Expressing-size-dependancy" data-toc-modified-id="Expressing-size-dependancy-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Expressing size dependancy</a></span></li></ul></li><li><span><a href="#Context-and-possible-aim" data-toc-modified-id="Context-and-possible-aim-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Context and possible aim</a></span><ul class="toc-item"><li><span><a href="#Aim" data-toc-modified-id="Aim-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Aim</a></span><ul class="toc-item"><li><span><a href="#Model-simulations" data-toc-modified-id="Model-simulations-10.1.1"><span class="toc-item-num">10.1.1&nbsp;&nbsp;</span>Model simulations</a></span><ul class="toc-item"><li><span><a href="#Conclusions-of-model-simulation-equlibria" data-toc-modified-id="Conclusions-of-model-simulation-equlibria-10.1.1.1"><span class="toc-item-num">10.1.1.1&nbsp;&nbsp;</span>Conclusions of model simulation equlibria</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Introduction: Bacterial competition, warming and size

# %% [markdown]
# Motivation: To examine how microbial communities and ecosystem function will respond to warming and disturbance (e.g. chemical pollution such as pesticides or antibiotics). This model investigates the impact of response of bacteria to warming based on different functional groups competing for the same resources. This will add to the small body of literature which emphasises that: 'food web response to temperature cannot be derived from the single species temperature response' [(Nomdedeuet al. 2013)](https://link.springer.com/content/pdf/10.1007%2Fs00227-012-1966-x.pdf). In most food web/low trophic/biogeochemical models changes to species/functional group interactions with warming are not considered.
#
# This model builds on the work by [Marsland et al. (2019)](https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1006793), which uses the seminal MacArthur (1970) species competition model. It includes a consumer pool (bacteria) and a resource pool (organic compounds). The bacteria can feed on specific resources only, and the resources consumed by the bacteria can be converted into other resources. Multiple bacteria with different functional traits (e.g. size, response to warmings (Thermal Performance Curves, TPCs), nutrient preference) compete for the same resourse. This notebook sets out the model and determines which traits are selected for under different environment and community scenarios.
#
# For detailed model description and explanation of the equations see this [notebook](https://nbviewer.jupyter.org/github/CleggTom/Bacteria_EcoFunc/blob/master/notebooks/Metabolic_model.ipynb) by Tom Clegg who built the initial model.

# %% [markdown]
# ## The Model
#
# ### Adaptation of Marsland
#
# #### Consumers
#
# For an $i$th consumers with $j$ resources the core consumer equation is:
#
# \begin{equation}
# dC_i/dt = C_i\Bigl(\sum_{j=1}^{M}U_{ij}S_j(1-\sum_{j \neq k}^{M}l_{jk}) - R_i\Bigl)
# \end{equation}

# %% [markdown]
# where $C_i$ is the biomass of consumer $i$, $u_{ij}$ is the preference of consumer $i$ to uptake resource $j$, $S_j$ is the mass or concentration of resources $j$, $l_{jk}$ is the proportion of $j$ taken up by the bacteria that is converted to and released as resource $k$, and $Rm_i$ is the maintenance cost loss term.

# %% [markdown]
# #### Resources
#
# For a $j$th resource the core equation is:
#
# \begin{equation}
# dS_j/dt = \rho_j - \sum_{i=1}^{N}\Bigl(C_iU_{ij}S_j-\sum_{j \neq k}^{M}C_iU_{ij}S_jl_{kj}\Bigl)
# \end{equation}
#
# where $\rho$ is the external input of resource $j$ and $l_{kj}$ is the gain and conversion of resource $j$ from $k$.
#
# #### Constraints
# |Parameter/Variable name | Param symbol | Units | Initial value |
# |---|---|---|---|
# |Bacteria | $C_i$ | cells/mL | 0.1 |
# |Resources | $S_j$ | g/mL | 1 |
# |Uptake | $U_{ij}$ | g/cells time | Temperature-dependant |
# |Respiration | $R_i$ | 1/time | Temperature-dependant |
# |Resource conversion efficiency | $v_j$ | cell/g | ? |
# |Monod function | $s_j$ | n.d | ? |
# |Half saturation constant | $K_j$ | g/mL | ? |
# |Excretion | $k_{jk}$ | n.d | 0.4 |
# |Resource supply | $\rho_j$ | g/mL time | 1 |
#
# \begin{array}{|c|c|c|}
# \hline Parameter/Variable & Dimension & Units & Constraint & Temp/size-dependant & Initial-value \\\hline
#   External-nutrient-supply, \rho_j & vector (,j) & mass/time & > 0 & no & 1 \\\hline
#   Nutrient-uptake, U_{ij} & matrix (i,j) & /masstime & > 0& yes & 1 \\\hline
#   Maintenance-respiration, R_i & vector (i,) & /time & >0, < 1& yes & 0.5 \\\hline
#   Excretion-to-new-nutrient, l_{jk} & matrix (j,k) & NA & < 1& no & 0.4 \\\hline
#   Resources, S & vector (j,) & mass& > 0 & NA & 1 \\\hline
#   Bacteria, C & vector (i,) & mass& > 0 & NA & 0.1 \\\hline
# \end{array}
#
# The above table sets our the contraints on the parameters and variables (nutrients and bacteria). There is another condition too that growth respiration and excretion must not sum to 1 or more ($Rg_j$ + $l_{jk}$ < 1) as otherwise no nutrient is gained by the bacteria.

# %% [markdown]
# ### Updated - Adaptation of Marsland and Pacciani
#
#
# #### Consumers
#
# For an $i$th consumers with $j$ resources the core consumer equation is:
#
# \begin{equation}
# dC_i/dt = C_i\Bigl(\sum_{j=1}^{M}U_{ij}s_jv_j(1-\sum_{j \neq k}^{M}l_{jk}) - R_i\Bigl)
# \end{equation}

# %% [markdown]
# where $C_i$ is the concentration of bacteria cells $i$, $u_{ij}$ is the preference of consumer $i$ to uptake resource $j$, $s_j$ is a function accounting for the fact that
# the dependence of a species’ growth rate on a given resource concentration saturates as the resource increases such that:
#
# \begin{equation}
# s_j = \frac{S_j}{K_j + S_j}
# \end{equation}
#
# where $S_j$ is the concentration of resources $j$ and $K_j$ is the half saturation constant of that resource.
# $l_{jk}$ is the proportion of $j$ taken up by the bacteria that is converted to and released as resource $k$, and $R_i$ is the respiration loss term.

# %% [markdown]
# #### Resources
#
# For a $j$th resource the core equation is:
#
# \begin{equation}
# dS_j/dt = \rho_j - \sum_{i=1}^{N}\Bigl(C_iU_{ij}s_j-\sum_{j \neq k}^{M}C_iU_{ij}s_jl_{kj}\Bigl)
# \end{equation}
#
# where $\rho$ is the external input of resource $j$ and $l_{kj}$ is the gain and conversion of resource $j$ from $k$.
#
# #### Constraints
#
# |Parameter/Variable name | Param symbol | Units | Initial value |
# |---|---|---|---|
# |Bacteria | $C_i$ | cells/mL | 0.1 |
# |Resources | $S_j$ | g/mL | 1 |
# |Uptake | $U_{ij}$ | g/cells time | Temperature-dependant |
# |Respiration | $R_i$ | 1/time | Temperature-dependant |
# |Resource conversion efficiency | $v_j$ | cell/g | ? |
# |Monod function | $s_j$ | n.d | ? |
# |Half saturation constant | $K_j$ | g/mL | ? |
# |Excretion | $k_{jk}$ | n.d | 0.4 |
# |Resource supply | $\rho_j$ | g/mL time | 1 |

# %% [markdown]
# ### Type I and Type II functional responses
#
#
# #### Type I
#
#
# \begin{equation}
# dC_i/dt = C_i\Bigl(\sum_{j=1}^{M}U_{ij}S_jv_j(1-\sum_{j \neq k}^{M}l_{jk}) - R_i\Bigl)
# \end{equation}
#
# \begin{equation}
# dS_j/dt = \rho_j - \sum_{i=1}^{N}\Bigl(C_iU_{ij}S_j-\sum_{j \neq k}^{M}C_iU_{ij}s_jl_{kj}\Bigl)
# \end{equation}

# %% [markdown]
# and where for both equations:
#
# \begin{equation}
# U_{ij}S_j = \frac{U_{ref}S_j}{S_{ref}}
# \end{equation}
#
# where $U_{ref}$ is the uptake at a level of resource $S_{ref}$.

# %%
import scipy as sc
import matplotlib.pyplot as plt

S = sc.linspace(1,100,101)
Sref = 50
Uref = 0.4
US = Uref * S / Sref

plt.plot(S, US,'k-')
plt.grid
plt.ylabel('Uptake (g/cells time)')
plt.xlabel('Resource (g/mL)')
#plt.title("C1 = 0:1, C2 = 0.5", fontsize=19)
plt.show()

# %% [markdown]
# #### Type II
#
#
# \begin{equation}
# dC_i/dt = C_i\Bigl(\sum_{j=1}^{M}U_{ij}S_j(1-\sum_{j \neq k}^{M}l_{jk}) - R_i\Bigl)
# \end{equation}
#
# \begin{equation}
# dS_j/dt = \rho_j - \sum_{i=1}^{N}\Bigl(C_iU_{ij}S_j-\sum_{j \neq k}^{M}C_iU_{ij}S_jl_{kj}\Bigl)
# \end{equation}
#
# and where for both equations:
#
# \begin{equation}
# U_{ij}S_j = \frac{U_{max}S_j}{K_j + S_j}
# \end{equation}
#
# where $K_j$ is the carrying capacity of resource $j$ and $U_{max}$ the max uptake of resource $j$ by species $i$.
#
#
# For both Type I and Type II the units $U_{ij}S_j$ are 1/time (i.e. $U_{ij}$). For different species ($i$), $U_{ref}$ and $U_{max}$ would vary to allow species to take up nutrients at different rates. In our system, this would be controlled by differing activation energies (and maybe different $B_0$).

# %%
import scipy as sc
import matplotlib.pyplot as plt

S = sc.linspace(1,100,101)
umax = 1
k = 25
US = umax * S / (k + S)

plt.plot(S, US,'k-')
plt.grid
plt.ylabel('Uptake (g/cells time)')
plt.xlabel('Resource (g/mL)')
#plt.title("C1 = 0:1, C2 = 0.5", fontsize=19)
plt.show()

# %% [markdown]
# #### Constraints
#
# |Parameter/Variable name | Param symbol | Units | Initial value |
# |---|---|---|---|
# |Bacteria | $C_i$ | g/mL | 0.1 |
# |Resources | $S_j$ | g/mL | 1 |
# |Uptake (reference and max) | $U_{ref}$ & $U_{max}$ | 1/ time | Temperature-dependant |
# |Resource reference value | $S_{ref}$ | g/mL | ? |
# |Half saturation constant | $K_j$ | g/mL | ? |
# |Excretion | $k_{jk}$ | n.d | 0.4 |
# |Respiration | $R_i$ | 1/time | Temperature-dependant |
# |Resource supply | $\rho_j$ | g/mL time | 1 |
#
# with $U_{max}$ and $R$:
# \begin{equation}
# U_{max} = B_{0U}M^{-0.25} * e^{\frac{-Ea_U}{k}\cdot\Bigl(\frac{1}{T} - \frac{1}{T_{ref}}\Bigl)}
# \end{equation}
#
# \begin{equation}
# R = B_{0R}M^{-0.25} * e^{\frac{-Ea_R}{k}\cdot\Bigl(\frac{1}{T} - \frac{1}{T_{ref}}\Bigl)}
# \end{equation}
#
# |Parameter/Variable name | Param symbol | Units | Initial value |
# |---|---|---|---|
# |Uptake |  $U_{max}$ | 1/ time | Temperature-dependant |
# |Respiration | $R$ | 1/time | Temperature-dependant |
# |Normalisation constant | $B_0$ | g/time| $B_{0R}$ < $B_{0U}$|
# |Mass | $M$ | g| 1 |
# |Activation Energy | $Ea$ | eV| $Ea_R$ < $Ea_U$|
# |Boltsmann constant | $k$ | ev/K| 0.0000862|
# |Reference Temperature | $T_{ref}$ | K| 273.15|
# |Temperature | $T$ | K| variable|

# %% [markdown]
# ### Comparison to the Marsland model
#
# #### The Marsland model
#
# The equations below set out the Marsland 2019 model.
#
# \begin{equation}
# dC_i/dt = g_iC_i\Bigl(\sum_{j=1}^{M}w_j\sigma U_{ij}S_j(1-\sum_{k=1}^{M}l_{jk}) - R_i\Bigl)
# \end{equation}
#
# \begin{equation}
# dS_j/dt = \rho_j + \sum_{i=1}^{N}C_i\Bigl(\sum_{k=1}^{M}\sigma U_{ij}S_j l_{kj} - \sigma U_{ij}S_j\Bigl)
# \end{equation}
#
# where $g_i$ is the proportional constant between per capita growth rate and energy flux, $w_j$ is the energy density of resource $j$ (units are energy/mass) and $\sigma$ is the functional response (units mass/time).
#
# #### Differences between ours and Marslands model
#
# - We do not parameterise energy density of resource ($w_j$) and therefore nor the constant between growth and energy flux ($g_i$)
# - We assume a Type I functional response ($\sigma$)
# - For Marsland $\rho_j$ = 0 except for $\rho_0$, so only the first resource has an external input which then diversifies. In our model all resources have an input.
# - We include the addition of respiration loss associated with growth ($R_g$) as a loss term in the Bacterial mass (dC/dt) equation.

# %% [markdown]
# ## 2-species 2-resources model
#
# ### Bacteria
#
# \begin{equation}
# dC_1/dt = C_1\Bigl(\Bigl(u_{11}S_1(1-(l_{12}+l_{21})) + u_{12}S_2(1-(l_{21}+l_{12}))\Bigl) - R_1\Bigl)
# \end{equation}
#
# \begin{equation}
# dC_2/dt = C_2\Bigl(\Bigl(u_{21}S_1(1-(l_{12}+l_{21})) + u_{22}S_2(1-(l_{21}+l_{12}))\Bigl) - R_2\Bigl)
# \end{equation}
#
# ### Resources
# \begin{equation}
# dS_1/dt = \rho_1 - \Bigl((C_1u_{11}S_1-   (C_1u_{11}S_1l_{21} + C_1u_{11}S_1l_{12})) + (C_2u_{21}S_1-   (C_2u_{21}S_1l_{21} + C_2u_{21}S_1l_{12}))\Bigl)
# \end{equation}
#
# \begin{equation}
# dS_2/dt = \rho_2 - \Bigl((C_1u_{12}S_2-   (C_1u_{12}S_2l_{12} + C_1u_{12}S_2l_{21})) + (C_2u_{22}S_2-   (C_2u_{22}S_2l_{12} + C_2u_{22}S_2l_{21}))\Bigl)
# \end{equation}

# %% [markdown]
# ## Modelling functional traits
#
# ### Temperature and size dependance
#
# In this model only $u_{ij}$ and $Rm_i$ can be temperature- and size-dependant as they are the only terms that explicitly depend on an individual consumer $i$. Temperature- and size-dependancy are formulated following the Metabolic Theory of Ecology and the Sharpe-Schoolfield equation. Such that:
#
#
# \begin{equation}
# u_{ij} = B_{u}M^{-0.25} * \frac{e^{\frac{-Ea}{k}\cdot\Bigl(\frac{1}{T} - \frac{1}{T_{ref}}\Bigl)}}{1 + \frac{Ea}{E_D - Ea}\cdot e^{\frac{-E_D}{k}\cdot\Bigl(\frac{1}{T_{pk}} - \frac{1}{T}\Bigl)}}
# \end{equation}
#
# \begin{equation}
# Rm_i = B_{rm}M^{-0.25} * \frac{e^{\frac{-Ea}{k}\cdot\Bigl(\frac{1}{T} - \frac{1}{T_{ref}}\Bigl)}}{1 + \frac{Ea}{E_D - Ea}\cdot e^{\frac{-E_D}{k}\cdot\Bigl(\frac{1}{T_{pk}} - \frac{1}{T}\Bigl)}}
# \end{equation}

# %% [markdown]
# where $BM^{-0.25}$ is the mass ($M$) scaled to $3/4$ / M = $M^{-0.25}$ multiplied by a constant that is higher for uptake ($u_{ij}$) than maintenance respiration ($Rm_i$). The second part of the equation is the Sharpe-Schoofield equation where $Ea$ is the activation energy in eV, $E_D$ is the deactivation energy after the temperature maximum metabolism is reached ($T_{pk}$), $T$ is the temperature and $T_{ref}$ is the reference temperature. All temperatures are expressed in Kelvin (K) and $k$ is the Boltzmann constant of $8.62 x 10^{-5} eV K^{-1}$.

# %% [markdown]
# ## Running the model
#
# Below imports code from the `Bacteria_vector_modular.py` file, which calls on `parameters.py`, `model_func.py` which contains the model equations and `size_temps_func.py`.
#
# It allows assembly of a community ($ass$) with the size of the community fixed ($N$), and allows the model to be run at different temperatures ($t_n$). Currently in the `Bacteria_vector_modular.py` code the starting temperature is 20 C (also the Topt).
#
# New parameter $Meta_{ratio}$ which allows to choose ratio between competitors (𝑈/𝑅𝑚), i.e. is it exactly the same ($Meta_{ratio}$ = 1), is it different ($Meta_{ratio}$!= 1).
#
# The model checks the code gets to steadt state. If you set $Meta_{ratio}$ very close to 1 can see this.

# %%
import Bacteria_vector_modular as bvm
import parameters as par
import model_func as mod
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc
import random

# Set up parameters
N = 10
M = 5
k = 0.0000862
Tref = 273.15 # 0 degrees C
Fg_num = 5
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_r = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
Ea_D = np.repeat(3.5,N) # Deactivation energy
t_n = 21 # number of temperatures 
t_n_output = (t_n * N) + N # number of rows in output array
t_fin = 200
t = sc.linspace(0,t_fin-1,t_fin)
ass = 1

### Metabolic ratio
# 'Random'
Meta_ratio_tmp = np.repeat(np.array([1, 1.1, 1, 0.9, 1]), 100)
Meta_ratio = np.array(random.choices(Meta_ratio_tmp, k=M))
# Forced
#Meta_ratio = np.array([1, 1.0002, 1, 0.9, 1])

x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))

bvm.ass_temp_run(t, N, M, t_n,  Tref, B_r, B_g, Ma, k, ass, Meta_ratio, x0, t_fin, T_pk, Ea_D, Fg_num)
# Out:
# Temperature = 20
#
# Assembly =  0
# Metabolic ratio between competitors[1.  1.  1.1 1.  1.1]
# 200
# Bacteria mass at equilibrium (C1 - C5)[0.496 0.293 1.276 0.451 1.644]
# Bacteria mass at equilibrium (C6 - C10)[0.496 0.593 0.    0.249 0.   ]
# Resource mass at equilibrium (S1 - S5)[0.429 0.429 0.429 0.428 0.43 ]
#
# Assembly =  1
# Metabolic ratio between competitors[1.  1.  1.1 1.  0.9]
# 300
# Bacteria mass at equilibrium (C1 - C5)[0.496 0.293 1.276 0.451 0.   ]
# Bacteria mass at equilibrium (C6 - C10)[0.496 0.593 0.    0.249 1.099]
# Resource mass at equilibrium (S1 - S5)[0.429 0.429 0.429 0.428 0.387]
# Temperature = 20
#
# Assembly =  0
# Metabolic ratio between competitors[1.  1.  1.1 0.9 1. ]
# 200
# Bacteria mass at equilibrium (C1 - C5)[0.496 0.293 1.276 0.    0.822]
# Bacteria mass at equilibrium (C6 - C10)[0.496 0.593 0.    1.106 0.822]
# Resource mass at equilibrium (S1 - S5)[0.429 0.429 0.429 0.385 0.43 ]

# %% [markdown]
# ## Equilibria solutions
#
# ### No competition for resources

# %% [markdown]
# M = N/2
#
# $Ea$ = 0.6 and 1.0
# $Ea_D$ = 3.5
# $T$ = 293.15
# $Tref$ = 273.15
# $k$ = 0.0000862
# $Ma$ = 1
# $U$ = 2.8 and 9.1
# $Rm$ = 0.56 and 1.8
# $l$ = 0.4
# $B_{rm}$ = 0.1
# $B_g$ = 0.5
# $\rho$ = 1

# %%
from sympy import *
u, S, Rg, Rm,a, C, rho, t = var("u,  S, Rg, Rm, a,C,  rho,t",real = True)

dC_dt = C * ((u * S * (1-a)) - Rm)
dS_dt = rho - ((u * S * C) - (u * S * C * a))
dC_dt, dS_dt
C_eqlb = Eq(dC_dt, 0)
S_eqlb = Eq(dS_dt, 0)
C_eqlb, S_eqlb
C_eqlb_sol = solve(C_eqlb, S)
S_eqlb_sol = solve(S_eqlb, C)
pretty_print(solve((C_eqlb,S_eqlb), C,S))
# Out:
# ⎡⎛ρ      -Rm   ⎞⎤
# ⎢⎜──, ─────────⎟⎥
# ⎣⎝Rm  u⋅(a - 1)⎠⎦

# %% [markdown]
# #### Phase plane (resource vs. bacteria)

# %%
#https://scipy-cookbook.readthedocs.io/items/LoktaVolterraTutorial.html

import pylab as p
import scipy as sc
import matplotlib.cm
from scipy import integrate

u = 2.84
a = 0.4
Rm = 0.57
row=1

def dX_dt(X, t = 0):
    dC = X[0] * ((u * X[1] * (1-a) - Rm))
    dS = row - (X[0] * X[1] * u) + (X[0] * X[1] * u * a)
    return np.array([dC, dS])
              
values  = sc.linspace(0.3, 0.9, 5)                          # position of X0 between X_f0 and X_f1
vcolors = p.cm.autumn_r(sc.linspace(0.3, 1., len(values)))  # colors for each trajectory

X_f0 = np.array([     0. ,  0.])
X_f1 = np.array([ row/Rm, -Rm/(u*(a-1))])

t = sc.linspace(0, 15,  1000)

f2 = p.figure()
for v, col in zip(values, vcolors):
    X0 = v * X_f1                               # starting point
    X = integrate.odeint( dX_dt, X0, t)         # we don't need infodict here
    p.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.1f, %.1f)' % ( X0[0], X0[1]) )

ymax = p.ylim(ymin=0)[1]                        # get axis limits
xmax = 2 #p.xlim(xmin=0)[1]
nb_points   = 20

x = sc.linspace(0, xmax, nb_points)
y = sc.linspace(0, ymax, nb_points)

X1 , Y1  = np.meshgrid(x, y)                       # create a grid

X1 , Y1 = X1,  Y1
DX1, DY1 = dX_dt([X1, Y1])                      # compute growth rate on the gridt
M = (np.hypot(DX1, DY1))                           # Norm of the growth rate 
M[ M == 0] = 1.                                 # Avoid zero division errors 
DX1 /= M                                        # Normalize each arrows
DY1 /= M

#-------------------------------------------------------
# Drow direction fields, using matplotlib 's quiver function
# I choose to plot normalized arrows and to use colors to give information on
# the growth speed
p.title('Trajectories and direction fields')
Q = p.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
p.xlabel('Number of Bacteria')
p.ylabel('Number of Resources')
p.legend()
p.grid()
p.xlim(0, xmax)
p.ylim(0, ymax)
# Out:
# (0, 0.7626046278873639)

# %% [markdown]
# #### Phase plane (bacteria vs. bacteria, C1 = C2)

# %%
#https://scipy-cookbook.readthedocs.io/items/LoktaVolterraTutorial.html
import scipy as sc

u = 2.84
a = 0.4
Rm = 0.57
row=1

def dX_dt(X, t = 0):
    dC = X[0] * ((u * X[2] * (1-a) - Rm))
    dC2 = X[1] * ((u * X[3] * (1-a) - Rm))
    dS = row - (X[0] * X[2] * u) + (X[0] * X[2] * u * a)
    dS2 = row - (X[1] * X[3] * u) + (X[1] * X[3] * u * a)
    return np.array([dC, dC2, dS, dS2])
              
values  = sc.linspace(0.3, 0.9, 5)                          # position of X0 between X_f0 and X_f1
vcolors = p.cm.autumn_r(sc.linspace(0.3, 1., len(values)))  # colors for each trajectory

X_f0 = np.array([     0. ,  0., 0., 0.])
X_f1 = np.array([ row/Rm, row/Rm, -Rm/(u*(a-1)), -Rm/(u*(a-1))])

t = sc.linspace(0, 15,  1000)

f2 = p.figure()
for v, col in zip(values, vcolors):
    X0 = v * X_f1                               # starting point
    X = integrate.odeint( dX_dt, X0, t)         # we don't need infodict here
    p.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.1f, %.1f)' % ( X0[0], X0[1]) )

ymax = 2#p.ylim(ymin=0)[1]                        # get axis limits
xmax = 2 #p.xlim(xmin=0)[1]
nb_points   = 20

x = sc.linspace(0, xmax, nb_points)
y = sc.linspace(0, ymax, nb_points)
z = sc.linspace(0, 1, nb_points)
b = sc.linspace(0, 1, nb_points)
  
X1 , Y1  = np.meshgrid(x, y)                       # create a grid
q = dX_dt([X1, Y1, z, b])  
DX1, DY1 = q[0,:,:] , q[1,:,:]                      # compute growth rate on the gridt
M = (np.hypot(DX1, DY1))                           # Norm of the growth rate 
M[ M == 0] = 1.                                 # Avoid zero division errors 
DX1 /= M                                        # Normalize each arrows
DY1 /= M

#-------------------------------------------------------
# Drow direction fields, using matplotlib 's quiver function
# I choose to plot normalized arrows and to use colors to give information on
# the growth speed
p.title('Trajectories and direction fields')
Q = p.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
p.xlabel('Number of Bacteria 1')
p.ylabel('Number of Bacteria 2')
p.legend()
p.grid()
p.xlim(0, xmax)
p.ylim(0, ymax)
# Out:
# (0, 2)

# %% [markdown]
# #### Phase plane (bacteria vs. bacteria, C1 != C2)

# %%
#https://scipy-cookbook.readthedocs.io/items/LoktaVolterraTutorial.html


u = 2.84
a = 0.4
Rm = 0.57
row=1
u2 = 9.04
Rm2 = 1.84

def dX_dt(X, t = 0):
    dC = X[0] * ((u * X[2] * (1-a) - Rm))
    dC2 = X[1] * ((u2 * X[3] * (1-a) - Rm2))
    dS = row - (X[0] * X[2] * u) + (X[0] * X[2] * u * a)
    dS2 = row - (X[1] * X[3] * u2) + (X[1] * X[3] * u2 * a)
    return np.array([dC, dC2, dS, dS2])
              
values  = sc.linspace(0.3, 0.9, 5)                          # position of X0 between X_f0 and X_f1
vcolors = p.cm.autumn_r(sc.linspace(0.3, 1., len(values)))  # colors for each trajectory

X_f0 = np.array([     0. ,  0., 0., 0.])
X_f1 = np.array([ row/Rm, row/Rm, -Rm/(u*(a-1)), -Rm/(u*(a-1))])

t = sc.linspace(0, 15,  1000)

f2 = p.figure()
for v, col in zip(values, vcolors):
    X0 = v * X_f1                               # starting point
    X = integrate.odeint( dX_dt, X0, t)         # we don't need infodict here
    p.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.1f, %.1f)' % ( X0[0], X0[1]) )

ymax = p.ylim(ymin=0)[1]                        # get axis limits
xmax = 2#p.xlim(xmin=0)[1]
nb_points   = 20

x = sc.linspace(0, xmax, nb_points)
y = sc.linspace(0, ymax, nb_points)
z = sc.linspace(0, 1, nb_points)
b = sc.linspace(0, 1, nb_points)
  
X1 , Y1  = np.meshgrid(x, y)                       # create a grid
q = dX_dt([X1, Y1, z, b])  
DX1, DY1 = q[0,:,:] , q[1,:,:]                      # compute growth rate on the gridt
M = (np.hypot(DX1, DY1))                           # Norm of the growth rate 
M[ M == 0] = 1.                                 # Avoid zero division errors 
DX1 /= M                                        # Normalize each arrows
DY1 /= M

#-------------------------------------------------------
# Drow direction fields, using matplotlib 's quiver function
# I choose to plot normalized arrows and to use colors to give information on
# the growth speed
p.title('Trajectories and direction fields')
Q = p.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
p.xlabel('Number of Bacteria 1')
p.ylabel('Number of Bacteria 2')
p.legend()
p.grid()
p.xlim(0, xmax)
p.ylim(0, ymax)
# Out:
# (0, 1.63817170535489)

# %% [markdown]
# ### Competition for resources

# %%
from sympy import *
import scipy as sc
u1, u2, S,  Rm1, Rm2, a,C1, C2,rho, t = var("u1, u2, S, Rm1, Rm2,a, C1, C2, rho,t",real = True)

dC1_dt = C1 * ((u1 * S * (1-a)) - Rm1)
dC2_dt = C2 * ((u2 * S * (1-a)) - Rm2)
dS_dt = rho - (((u1 * S * C1) - (u1 * S * C1 *a)) + ((u2 * S * C2) - (u2 * S * C2 *a)))
dC1_dt, dC2_dt, dS_dt
C1_eqlb = Eq(dC1_dt, 0)
C2_eqlb = Eq(dC2_dt, 0)
S_eqlb = Eq(dS_dt, 0)

pretty_print(solve((C1_eqlb,C2_eqlb, S_eqlb), C1,C2,S))
# Out:
# ⎡⎛    ρ     -Rm₂   ⎞  ⎛ ρ        -Rm₁   ⎞⎤
# ⎢⎜0, ───, ─────────⎟, ⎜───, 0, ─────────⎟⎥
# ⎣⎝   Rm₂  a⋅u₂ - u₂⎠  ⎝Rm₁     a⋅u₁ - u₁⎠⎦

# %% [markdown]
# Using the same paramterisations as above (E for C1 = 0.6 and E for C2 = 1.0) and assuming M = N/2 the solutions are:
#
# C1 = 0, C2 = 0.55, S1 = 0.33 and
#
# C1 = 1.76, C2 = 0, S1 = 0.33

# %%
from sympy import *
import scipy as sc
u1, u2, S,  Rm1, Rm2, a,k,v,C1, C2,rho, t = var("u1, u2, S, Rm1, Rm2,a, k,v,C1, C2, rho,t",real = True)

dC1_dt = C1 * (((u1 * S * v * (1-a))/(k + S)) - Rm1)
dC2_dt = C2 * (((u2 * S * v * (1-a))/(k + S)) - Rm2)
dS_dt = rho - ((((u1 * S * C1)/(k + S)) - ((u1 * S * C1 *a))/(k + S)) + (((u2 * S * C2)/(k + S)) - ((u2 * S * C2 *a)/(k + S))))
dC1_dt, dC2_dt, dS_dt
C1_eqlb = Eq(dC1_dt, 0)
C2_eqlb = Eq(dC2_dt, 0)
S_eqlb = Eq(dS_dt, 0)

pretty_print(solve((C1_eqlb,C2_eqlb, S_eqlb), C1,C2,S))
# Out:
# ⎡⎛   ρ⋅v        -Rm₂⋅k       ⎞  ⎛ρ⋅v           -Rm₁⋅k       ⎞⎤
# ⎢⎜0, ───, ───────────────────⎟, ⎜───, 0, ───────────────────⎟⎥
# ⎣⎝   Rm₂  Rm₂ + a⋅u₂⋅v - u₂⋅v⎠  ⎝Rm₁     Rm₁ + a⋅u₁⋅v - u₁⋅v⎠⎦

# %% [markdown]
# #### Type I functional response

# %%
from sympy import *
import scipy as sc
u1ref, Sref, u2ref, S,v, a, R1, R2,C1, C2,rho, t = var("u1ref, Sref, u2ref, S,v,a, R1, R2,C1, C2, rho,t",real = True)

dC1_dt = C1 * (((u1ref * S/Sref) * v * (1-a)) - R1)
dC2_dt = C2 * (((u2ref * S/Sref) * v * (1-a)) - R2)
dS_dt = rho - ((((u1ref * S/Sref) * C1) - ((u1ref * S/Sref) * C1 *a)) + (((u2ref * S/Sref) * C2)- ((u2ref * S/Sref) * C2 *a)))
dC1_dt, dC2_dt, dS_dt
C1_eqlb = Eq(dC1_dt, 0)
C2_eqlb = Eq(dC2_dt, 0)
S_eqlb = Eq(dS_dt, 0)

pretty_print(solve((C1_eqlb,C2_eqlb, S_eqlb), C1,C2,S))
# Out:
# ⎡⎛   ρ⋅v       -R₂⋅Sref      ⎞  ⎛ρ⋅v          -R₁⋅Sref      ⎞⎤
# ⎢⎜0, ───, ───────────────────⎟, ⎜───, 0, ───────────────────⎟⎥
# ⎣⎝    R₂  a⋅u2ref⋅v - u2ref⋅v⎠  ⎝ R₁     a⋅u1ref⋅v - u1ref⋅v⎠⎦

# %% [markdown]
# Stationary points:
#
# \begin{equation}
# R* = \frac{RS_{ref}}{vU_{ref}(1-l)}
# \end{equation}
#
# or as previously:
#
# \begin{equation}
# R* = \frac{R}{U(1-l)}
# \end{equation}
#
# \begin{equation}
# C = \frac{\rho v}{R}
# \end{equation}
#
#
# For when $U/R$ are equal the equilibrium is a line of points along:
#
# \begin{equation}
# C_1 = \frac{\rho v S_{ref} - C_2R_2}{R_1}
# \end{equation}
#
# \begin{equation}
# C_2 = \frac{\rho v S_{ref} - C_1R_1}{R_2}
# \end{equation}

# %% [markdown]
# #### Type II functional response

# %%
from sympy import *
import scipy as sc
u1max, u2max, S,k, a, R1, R2,C1, C2,rho, t = var("u1max, u2max, S, k,a,R1, R2,C1, C2, rho,t",real = True)

dC1_dt = C1 * (((u1max * S)/(k+S) * (1-a)) - R1)
dC2_dt = C2 * (((u2max * S)/(k+S) * (1-a)) - R2)
dS_dt = rho - ((((u1max * S)/(k+S) * C1) - ((u1max * S)/(k+S) * C1 *a)) + (((u2max * S)/(k+S) * C2)- ((u2max * S)/(k+S) * C2 *a)))
dC1_dt, dC2_dt, dS_dt
C1_eqlb = Eq(dC1_dt, 0)
C2_eqlb = Eq(dC2_dt, 0)
S_eqlb = Eq(dS_dt, 0)

pretty_print(solve((C1_eqlb,C2_eqlb, S_eqlb), C1,C2,S))
# Out:
# ⎡⎛   ρ          -R₂⋅k        ⎞  ⎛ρ             -R₁⋅k        ⎞⎤
# ⎢⎜0, ──, ────────────────────⎟, ⎜──, 0, ────────────────────⎟⎥
# ⎣⎝   R₂  R₂ + a⋅u2max - u2max⎠  ⎝R₁     R₁ + a⋅u1max - u1max⎠⎦

# %% [markdown]
# Stationary points:
#
# \begin{equation}
# R* = \frac{RK}{U_{max}(1-l) - R}
# \end{equation}
#
# \begin{equation}
# C = \frac{\rho}{R}
# \end{equation}
#
#
# For when $U/R$ are equal the equilibrium is a line of points along:
#
# \begin{equation}
# C_1 = \frac{\rho v k - C_2R_2}{R_1} + \frac{\rho}{R_1U_{max1}(1-l)}
# \end{equation}
#
# \begin{equation}
# C_2 = \frac{\rho v k - C_1R_1}{R_2}+ \frac{\rho}{R_2U_{max2}(1-l)}
# \end{equation}

# %%
import scipy as sc
import matplotlib.pyplot as plt
import numpy as np

K = 1
#R = np.array([1.1, 2.3, 3.4, 4.5, 2])
R = sc.linspace(3, 0.5, 100)
#U = np.array([10, 20, 30, 40, 50])
U = sc.linspace(5, 50, 100)
v = 1
l = 0.4
S = (R * K)/ ( (v * U * (1-l)) - R)

#print(R)
#print(S)

plt.plot(U/R, S,'k-')
plt.grid
plt.ylabel('R*')
plt.xlabel('U/R')
plt.title('Type II')
plt.show()




#R = np.array([1.1, 2.3, 3.4, 4.5, 2])
R = sc.linspace(3, 0.5, 100)
#U = np.array([10, 20, 30, 40, 50])
U = sc.linspace(5, 50, 100)
l = 0.4
S = (R)/ ( U * (1-l))

#print(U/R)
#print(S)

plt.plot(U/R, S,'k-')
plt.grid
plt.ylabel('R*')
plt.xlabel('U/R')
plt.title('Original model version (Type I)')
plt.show()
# Out:
# [3.         2.97474747 2.94949495 2.92424242 2.8989899  2.87373737
#  2.84848485 2.82323232 2.7979798  2.77272727 2.74747475 2.72222222
#  2.6969697  2.67171717 2.64646465 2.62121212 2.5959596  2.57070707
#  2.54545455 2.52020202 2.49494949 2.46969697 2.44444444 2.41919192
#  2.39393939 2.36868687 2.34343434 2.31818182 2.29292929 2.26767677
#  2.24242424 2.21717172 2.19191919 2.16666667 2.14141414 2.11616162
#  2.09090909 2.06565657 2.04040404 2.01515152 1.98989899 1.96464646
#  1.93939394 1.91414141 1.88888889 1.86363636 1.83838384 1.81313131
#  1.78787879 1.76262626 1.73737374 1.71212121 1.68686869 1.66161616
#  1.63636364 1.61111111 1.58585859 1.56060606 1.53535354 1.51010101
#  1.48484848 1.45959596 1.43434343 1.40909091 1.38383838 1.35858586
#  1.33333333 1.30808081 1.28282828 1.25757576 1.23232323 1.20707071
#  1.18181818 1.15656566 1.13131313 1.10606061 1.08080808 1.05555556
#  1.03030303 1.00505051 0.97979798 0.95454545 0.92929293 0.9040404
# ...

# %% [markdown]
# #### Phase plane (bacteria vs. bacteria, C1 != C2)

# %%
#https://scipy-cookbook.readthedocs.io/items/LoktaVolterraTutorial.html
import matplotlib.cm
import pylab as p
from scipy import integrate


u = 2.84
a = 0.4
Rm = 0.57
row=1
u2 = 9.06
Rm2 = 1.81

def dX_dt(X, t = 0):
    dC = X[0] * ((u * X[2] * (1-a) - Rm))
    dC1 = X[1] * ((u2 * X[2] * (1-a) - Rm2))
    dS = row - (X[0] * X[2] * u) + (X[0] * X[2] * u * a) - (X[1] * X[2] * u2) + (X[1] * X[2] * u2 * a)
    return np.array([dC, dC1, dS])
              
values  = sc.linspace(0.3, 0.9, 5)                          # position of X0 between X_f0 and X_f1
vcolors = p.cm.autumn_r(sc.linspace(0.3, 1., len(values)))  # colors for each trajectory

X_f0 = np.array([     0. ,  0. , 0.])
X_f1 = np.array([ row/Rm, 0., -Rm/(u*(a-1))])

t = sc.linspace(0, 15,  1000)

f2 = p.figure()
for v, col in zip(values, vcolors):
    X0 = v * X_f1                               # starting point
    X = integrate.odeint( dX_dt, X0, t)         # we don't need infodict here
    p.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.1f, %.1f)' % ( X0[0], X0[1]) )

ymax = p.ylim(ymin=0)[1]                        # get axis limits
xmax = 2#p.xlim(xmin=0)[1]
nb_points   = 20

x = sc.linspace(0, xmax, nb_points)
y = sc.linspace(-0.01, ymax, nb_points)
z = sc.linspace(0, 1, nb_points)

X1 , Y1  = np.meshgrid(x, y)                       # create a grid
q = dX_dt([X1, Y1, z])  
DX1, DY1 = q[0,:,:] , q[1,:,:]                      # compute growth rate on the gridt
M = (np.hypot(DX1, DY1))                           # Norm of the growth rate 
M[ M == 0] = 1.                                 # Avoid zero division errors 
DX1 /= M                                        # Normalize each arrows
DY1 /= M

#-------------------------------------------------------
# Drow direction fields, using matplotlib 's quiver function
# I choose to plot normalized arrows and to use colors to give information on
# the growth speed
p.title('Trajectories and direction fields')
Q = p.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
p.xlabel('Number of Bacteria 1')
p.ylabel('Number of Bacteria 2')
p.legend()
p.grid()
p.xlim(0, xmax)
p.ylim(-0.01, ymax)
# Out:
# (-0.01, 0.05500000000000001)

# %% [markdown]
# #### Phase plane (bacteria vs. bacteria, C1 = C2)
# This is the solution the model finds, when two individuals have the same growth and respiration rate (thereby still satisfying Eq 13 below) then the two can co-exist. This scenario is likely in a bloom/high-nutrient scenario when just a few species dominate [(O'Brien, 1974)](https://www.jstor.org/stable/1934626?seq=1).

# %%
#https://scipy-cookbook.readthedocs.io/items/LoktaVolterraTutorial.html

u = 2.84
a = 0.4
Rm = 0.57
row=1

def dX_dt(X, t = 0):
    dC = X[0] * ((u * X[2] * (1-a) - Rm))
    dC1 = X[1] * ((u * X[2] * (1-a) - Rm))
    dS = row - (X[0] * X[2] * u) + (X[0] * X[2] * u * a) - (X[0] * X[2] * u) + (X[0] * X[2] * u * a)
    return np.array([dC, dC1, dS])
              
values  = sc.linspace(0.3, 0.9, 5)                          # position of X0 between X_f0 and X_f1
vcolors = p.cm.autumn_r(sc.linspace(0.3, 1., len(values)))  # colors for each trajectory

X_f0 = np.array([     0. ,  0. , 0.])
X_f1 = np.array([ row/(2*Rm), row/(2*Rm), -Rm/(u*(a-1))])

t = sc.linspace(0, 15,  1000)

f2 = p.figure()
for v, col in zip(values, vcolors):
    X0 = v * X_f1                               # starting point
    X = integrate.odeint( dX_dt, X0, t)         # we don't need infodict here
    p.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.1f, %.1f)' % ( X0[0], X0[1]) )

ymax = p.ylim(ymin=0)[1]                        # get axis limits
xmax = 1 #p.xlim(xmin=0)[1]
nb_points   = 20

x = sc.linspace(0, xmax, nb_points)
y = sc.linspace(0, ymax, nb_points)
z = sc.linspace(0, 1, nb_points)

X1 , Y1  = np.meshgrid(x, y)                       # create a grid
q = dX_dt([X1, Y1, z])  
DX1, DY1 = q[0,:,:] , q[1,:,:]                      # compute growth rate on the gridt
M = (np.hypot(DX1, DY1))                           # Norm of the growth rate 
M[ M == 0] = 1.                                 # Avoid zero division errors 
DX1 /= M                                        # Normalize each arrows
DY1 /= M

#-------------------------------------------------------
# Drow direction fields, using matplotlib 's quiver function
# I choose to plot normalized arrows and to use colors to give information on
# the growth speed
p.title('Trajectories and direction fields')
Q = p.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
p.xlabel('Number of Bacteria 1')
p.ylabel('Number of Bacteria 2')
p.legend()
p.grid()
p.xlim(0, xmax)
p.ylim(0, ymax)
# Out:
# (0, 0.9086026603073724)

# %% [markdown]
# ### Co-existence under competition for resources
#
# The numerical simulation when M = N/2 (i.e. bacteria compete for resources) always results in co-existence. The condition to achieve coexistence is:
#
# \begin{equation}
# \frac{U_i}{Rm_i} = \frac{U_m}{Rm_m}
# \end{equation}
#
# where $U$ is the uptake, $R_m$ is the respiration and $i$ and $m$ are different bacterial species. If this constraint is not met then one of the bacteria will go extinct (as in Section 6.1.1).
#
# From a biological stand-point, this 'special' case may persist in nature. It does not result in equal mass of both competiting species, one always dominantes. In nature although you often get dominanting species, particularly when nutrients are high, other species are able to co-exist but with lower biomass. Here the species with the highest $U$ and $R_m$ wins, whereas when M = N then the species with the lowest $U$ and $R_m$ wins (perhaps due to lower loss).
#
# The condition here (Eq 13) implies that there is a constant relationship held across all species between the proportion of carbon taken up ($U$) and the proportion of carbon lost to respiration ($R$). So bacteria that ingest more carbon have a higher respiration cost. Currently, $U$ and $R$ are a function of the Boltzmann-Arrhenius equation. Eq 13 holds if both $U$ and $R$ have the same activation energy ($E$), but also if they have different $E$'s, so long as the $E$ values are in the same ratio as the other species. A modelling study by [O'Brien (1974)](https://www.jstor.org/stable/1934626?seq=1) shows that phytoplankton will co-exist if the ratios of half-saturation constant, death and growth rates are equal across species, similar to Eq 13.
#
# Sympy was unable to find the analytical solutions yielding the same result as the model. This is because there are multiple stationary points where the two competiting species can co-exist.
#
# Currently we have found a solution for the bacteria as a function of the other bacterial mass and the resource:
#
# \begin{equation}
# C1 = \frac{\rho - R_2C2}{R_1}
# \end{equation}
#
# \begin{equation}
# C2 = \frac{\rho - R_1C1}{R_2}
# \end{equation}
#
# and the resource equation is the same as for the other solutions:
#
# \begin{equation}
# S = \frac{R_1}{U_1(1-a)}
# \end{equation}
#
#
#  - Why so many stationary points with Eq 14 and 15, how do you realise this?
#  - Is it too rare for nature if unstable, or does it explain co-existence?
#  - Why does simulation always find this solution and not the extinction one?
#  - Is Eq 16 (S) also the R*?
#  - How to study this solution analytically?
#  - If we decide it is relevant, could we explore simulating a high nutrient scenario (competitive exclusion) and low nutrient scenario (coexistence)?
#  - Why is there a switch between whether the bacteria with the highest $U$ or $R_m$ wins or not between M = N and M = N/2?

# %% [markdown]
# #### Phase plane analysis

# %%
import matplotlib.pyplot as plt
import scipy as sc

# set any U1, U2 and Rm1 that you like
U1 = 10
U2 = 20
Rm1 = 1

# set any p or a that you like
p = 1
a = 0.4

# use this eq. to set Rm2 - this is a condition on having interior stationary points
Rm2 = U2*Rm1/U1

# set any C2 that you like (zero or non zero)
C2 = sc.linspace(0,0.5,50)

# use these eqs. to set C1 and S
C1 = (p - (Rm2 * C2)) / Rm1
S1 = Rm1 / (U1 * (1 - a))
#C2_other <- (p - (Rm1 * C1))/Rm2


#print(C1); print(C2)
print(np.array([(C1[0]),(C2[0]),(S1)]))

out = np.empty((0,N+M))
U = np.array([[U1], [U2]])
Rm = np.array([Rm1, Rm2])

B1 = sc.linspace(0,1,100)
B2 = sc.linspace(0,0.5,100)

for i in range(len(B1)):
    x0 = np.array([B1[i],0.5,S1])
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)

    # Run model
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = pars)
    pops = np.round(pops, 3)
    out = np.append(out, np.column_stack(pops[t_fin-1,:]), axis=0)
#print('C1 = ' + str(pops[t_fin-1,0]), ', C2 = ' + str(pops[t_fin-1,1]), ', S1 = ' + str(pops[t_fin-1,2]))
#print('U/Rm = ' + str(np.round(np.diag(U/Rm),3)))

plt.plot(C1, C2,'ro')
plt.grid
plt.scatter(out[:,0], out[:,1], s=100)
plt.ylabel('Bacteria 2')
plt.xlabel('Bacteria 1')
plt.title("C1 = 0:1, C2 = 0.5", fontsize=19)
plt.show()
# Out:
# [1.         0.         0.16666667]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a6a9ce3d39ca> in <module>
#      35 for i in range(len(B1)):
#      36     x0 = np.array([B1[i],0.5,S1])
# ---> 37     pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
#      38
#      39     # Run model
#
# NameError: name 'Rg' is not defined

# %%
import matplotlib.pyplot as plt
import scipy as sc
import numpy as np

N = 2
M = 1

# set any U1, U2 and Rm1 that you like
U1 = 10.0
U2 = 20.0
Rm1 = 1

# set any p or a that you like
p = 1
a = 0.4

# use this eq. to set Rm2 - this is a condition on having interior stationary points
Rm2 = U2*Rm1/U1

# set any C2 that you like (zero or non zero)
C2 = sc.linspace(0,0.5,50)

# use these eqs. to set C1 and S
C1 = (p - (Rm2 * C2)) / Rm1
S1 = Rm1 / (U1 * (1 - a))
#C2_other <- (p - (Rm1 * C1))/Rm2


#print(C1); print(C2)
print(np.array([(C1[0]),(C2[0]),(S1)]))

out = np.empty((0,N+M))
U = np.array([[U1], [U2]])
Rm = np.array([Rm1, Rm2])

B1 = sc.linspace(0,1,10)
B2 = sc.linspace(0,0.5,100)
t_fin = 10
t = sc.linspace(0,t_fin-1,t_fin)

plt.plot(C1, C2,'ro')
plt.grid

for i in range(len(B1)):
    x0 = np.array([B1[i],0.1,S1])
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    # Run model
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = pars)
    pops = np.round(pops, 3)
    sub = sc.linspace(0,9,11, dtype='int')
    pops_sub = pops[sub]
    plt.scatter(pops_sub[:,0], pops_sub[:,1], s=100)

#out = np.append(out, np.column_stack(pops[t_fin-1,:]), axis=0)
#print('C1 = ' + str(pops[t_fin-1,0]), ', C2 = ' + str(pops[t_fin-1,1]), ', S1 = ' + str(pops[t_fin-1,2]))
#print('U/Rm = ' + str(np.round(np.diag(U/Rm),3)))

plt.ylabel('Bacteria 2')
plt.xlabel('Bacteria 1')
plt.title("C1 = 0:1, C2 = 0.1", fontsize=19)
plt.show()



plt.plot(C1, C2,'ro')
plt.grid

for i in range(len(B1)):
    x0 = np.array([B1[i],0.5,S1])
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    # Run model
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = pars)
    pops = np.round(pops, 3)
    sub = sc.linspace(0,9,11, dtype='int')
    pops_sub = pops[sub]
    plt.scatter(pops_sub[:,0], pops_sub[:,1], s=100)

#out = np.append(out, np.column_stack(pops[t_fin-1,:]), axis=0)
#print('C1 = ' + str(pops[t_fin-1,0]), ', C2 = ' + str(pops[t_fin-1,1]), ', S1 = ' + str(pops[t_fin-1,2]))
#print('U/Rm = ' + str(np.round(np.diag(U/Rm),3)))

plt.ylabel('Bacteria 2')
plt.xlabel('Bacteria 1')
plt.title("C1 = 0:1, C2 = 0.5", fontsize=19)
plt.show()
# Out:
# [1.         0.         0.16666667]

# %% [markdown]
# - Because line of points, when diverge from one of the points goes back to this line. So it seems like not going to stable point but it is. $S$ is stable.

# %% [markdown]
# ### Investigating all solutions
#
# Finding if the analytical and the simulated equilibrium solutions are stable, and if so, when perturbed do they converge back to the stable point or diverge away.
#
# |Scenarios | Method | N | M |$Ea_{C1}$| $Ea_{C2}$| C1 | C2 | S1 | S2 | Equil point| Con-/Diverge| Notes |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# |1a | Emma | 2 | 2 | 0.6 | 0.6 | 1.76 | 1.76 | 0.33 | 0.33 | Yes | Converges |
# |1a | Sympy | 2 | 2 | 0.6 | 0.6 | 1.76 | 1.76 | 0.33 | 0.33 | Yes | Converges |
# |1a | Simulation | 2 | 2 | 0.6 | 0.6 | 1.76 | 1.76 | 0.33 | 0.33 | Yes | Converges |
# |1b | Emma | 2 | 2 | 0.6 | 1.0 | 1.76 |0.55 | 0.33 | 0.33 | Yes | Converges |
# |1b | Sympy | 2 | 2 | 0.6 | 1.0 | 1.76 | 0.55 | 0.33 | 0.33 | Yes | Converges |
# |1b | Simulation | 2 | 2 | 0.6 | 1.0 | 1.76 |0.55 | 0.33 | 0.33 | Yes | Converges |
# |2a| Emma | 2 | 1 | 0.6 | 0.6 | 1.76 | 1.76 | 0.33 | NA | No |  NA | C1 or C2 should be 0, both cannot be >0
# |2a| Sympy | 2 | 1 | 0.6 | 0.6 | 0.00 <br/> 1.76 | 1.76 <br/> 0 | 0.33 | NA | Yes |  Converges
# |2a | Simulation | 2 | 1 | 0.6 | 0.6 | 0.88 | 0.88 | 0.33 | NA | Yes | Converges |  = 50 % of scenario 1 a
# |2b| Emma | 2 | 1 | 0.6 | 1.0 | 1.76 | 0.55 | 0.33 | NA | No | NA | C1 or C2 should be 0, <br/> both cannot be >0 at these values (see Simulation 2b)
# |2b| Sympy | 2 | 1 | 0.6 | 1.0 | 0.00 <br/> 1.76 | 0.55 <br/> 0| 0.33 | NA | Yes | Converges
# |2b | Simulation | 2 | 1 | 0.6 | 1.0 | 0.17 | 0.50 | 0.33 | NA | Yes | Diverges |     Only one with a stable point to diverge <br/> not sure how to work this out from 1b like we can do with 2a.....FALSE EQUILIBRIUM?
#
#
# Note, changes in who winds depending on whether M = N (smaller Ea wins) or M = N/2 (larger Ea wins).

# %% [markdown]
# ## 3-species 1-resource system

# %%
# not yet working for a 3-species system

import Bacteria_vector_modular as bvm
import parameters as par
import model_func as mod
import size_temp_funcs
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc
import random

# Set up parameters
N = 3
M = 1
Fg_num = 5
k = 0.0000862
Tref = 273.15 # 0 degrees C
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_r = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
Ea_D = np.repeat(3.5,N) # Deactivation energy
t_n = 21 # number of temperatures 
t_n_output = (t_n * N) + N # number of rows in output array
t_fin = 200
t = sc.linspace(0,t_fin-1,t_fin)
ass = 1
Meta_ratio_tmp = np.repeat(np.array([1, 1.1, 1, 0.9, 1]), N)
Meta_ratio = np.array(random.choices(Meta_ratio_tmp, k=M))
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))

bvm.ass_temp_run(t, N, M, t_n,  Tref, B_r, B_g, Ma, k, ass, Meta_ratio, x0, t_fin, T_pk, Ea_D, Fg_num)
# Out:
# Temperature = 20
#
# Assembly =  0
# Metabolic ratio between competitors[1.1]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-69-b8b16ed597ac> in <module>
#      33 x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
#      34
# ---> 35 bvm.ass_temp_run(t, N, M, t_n,  Tref, B_r, B_g, Ma, k, ass, Meta_ratio, x0, t_fin, T_pk, Ea_D, Fg_num)
#
# ~/Documents/Chemical_Stressors/Models/Bacteria_Model/Code/Bacteria_vector_modular.py in ass_temp_run(t, N, M, t_n, Tref, B_r, B_g, Ma, k, ass, Meta_ratio, x0, t_fin, T_pk, Ea_D, Fg_num)
#      98
#      99             # Set up model
# --> 100             U = par.params(N, M, T, k, Tref, T_pk, B_g, B_r,Ma, Ea_U, Ea_R, Ea_D, Meta_ratio)[0] # make less than 1
#     101             R = par.params(N, M, T, k, Tref, T_pk, B_g, B_r,Ma, Ea_U, Ea_R, Ea_D, Meta_ratio)[1] # make less than 1
# ...

# %% [markdown]
# ## Time to equilibrium
#
# ... when move away from condition U1/Rm1 = U2/Rm2.
#
# All equilibrium points lead to one bacteria going extinct apart from where $U_1$/$R_{m1}$ = $U_2$/$R_{m2}$ is satisfied. At this latter point the timesteps to equilibrium is shortest (4 time steps) and either side of this is largest, see below.

# %% [markdown]
# ### 2-species system, long simulation time

# %%
import Vector_Testing_model as vtm
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc
import statistics as stat


# Set up parameters

# U = 10, 20, 30

N = 2
M = 1
t_fin = 100
k = 0.0000862
Tref = 273.15 # 0 degrees C
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_rm = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
T = 273.15 + 20
Ea_U = np.concatenate([np.repeat(0.6,N)])
Ea_R = np.concatenate([np.repeat(0.9, N)])
Ea_D = np.repeat(3.5,N) # Deactivation energy
t_fin = 20000 # 20,000 timesteps sees all reached equilibrium
t = sc.linspace(0,t_fin-1,t_fin)
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))

ratio = sc.linspace(0.9,1.1,1001)
time_eq = np.array([])
act_ratio = np.array([])
Urm = np.array([])

for i in range(len(ratio)): 

    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio[i]])


    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq = np.append(time_eq, len(np.unique(pops, axis=0)))
    U.shape = 2
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio = np.append(act_ratio, Urm)

#print(sum(np.diff(U/Rm)))
#print(act_ratio)
#print(Urm)
# Out:
# [-0.     0.095 -0.     0.091  0.089  0.167]

# %%
ratio = np.delete(ratio, int((len(ratio)+1)/2))
time_eq = np.delete(time_eq, int((len(ratio)+1)/2))

plt.plot(ratio, time_eq,'ko', markersize=4)
plt.grid
plt.xlabel('Metabolic Ratio (U1/Rm1 : U2/Rm2)')
plt.ylabel('Timesteps to monodominance')
plt.show()

# %% [markdown]
# ### 2 - 5 species system, 2 different functional groups

# %% [markdown]
# #### Type I
# ##### Code

# %%
#### Same bacteria mass in system

# Set up parameters

# U = 10, 20, 30
import Vector_Testing_model as vtm
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc
import statistics as stat

typ = 1
t_fin = 1000
k = 0.0000862
Tref = 273.15 # 0 degrees C
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_rm = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
T = 273.15 + 20
Ea_U = np.concatenate([np.repeat(0.6,N)])
Ea_R = np.concatenate([np.repeat(0.9, N)])
Ea_D = np.repeat(3.5,N) # Deactivation energy
t = sc.linspace(0,t_fin-1,t_fin)
K = 100

N = 2
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio = sc.linspace(0.9,1.1,11)
time_eq = np.array([])
act_ratio = np.array([])
Urm = np.array([])

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq = np.append(time_eq, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio = np.append(act_ratio, Urm)

N = 3
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio_3 = sc.linspace(0.9,1.1,11)
time_eq_3 = np.array([])
act_ratio_3 = np.array([])
Urm = np.array([])

for i in range(len(ratio_3)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_3[i], 3*ratio_3[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_3 = np.append(time_eq_3, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_3 = np.append(act_ratio_3, Urm)

N = 4
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio_4 = sc.linspace(0.9,1.1,11)
time_eq_4 = np.array([])
act_ratio_4 = np.array([])
Urm = np.array([])

for i in range(len(ratio_4)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_4[i], 3*ratio_4[i], 4*ratio_4[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_4 = np.append(time_eq_4, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_4 = np.append(act_ratio_4, Urm)

N = 5
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio_5 = sc.linspace(0.9,1.1,11)
time_eq_5 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(ratio_5)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_5 = np.append(time_eq_5, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_5 = np.append(act_ratio_5, Urm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1851e4a18d98> in <module>
#      22 Ma = 1 # Mass
#      23 T = 273.15 + 20
# ---> 24 Ea_U = np.concatenate([np.repeat(0.6,N)])
#      25 Ea_R = np.concatenate([np.repeat(0.9, N)])
#      26 Ea_D = np.repeat(3.5,N) # Deactivation energy
#
# NameError: name 'N' is not defined

# %%
#### Increasing biomass with increasing species

import Vector_Testing_model as vtm
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc
import statistics as stat
# Set up parameters

typ = 1

# U = 10, 20, 30
t_fin = 1000
k = 0.0000862
Tref = 273.15 # 0 degrees C
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_rm = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
T = 273.15 + 20
Ea_U = np.concatenate([np.repeat(0.6,N)])
Ea_R = np.concatenate([np.repeat(0.9, N)])
Ea_D = np.repeat(3.5,N) # Deactivation energy
t = sc.linspace(0,t_fin-1,t_fin)
K = 100

N = 2
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio = sc.linspace(0.9,1.1,11)
time_eq2 = np.array([])
act_ratio2 = np.array([])
Urm = np.array([])

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq2 = np.append(time_eq2, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio2 = np.append(act_ratio2, Urm)

N = 3
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio_3 = sc.linspace(0.9,1.1,11)
time_eq3_3 = np.array([])
act_ratio_3 = np.array([])
Urm = np.array([])

for i in range(len(ratio_3)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_3[i], 3*ratio_3[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq3_3 = np.append(time_eq3_3, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_3 = np.append(act_ratio_3, Urm)

N = 4
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio_4 = sc.linspace(0.9,1.1,11)
time_eq4_4 = np.array([])
act_ratio_4 = np.array([])
Urm = np.array([])

for i in range(len(ratio_4)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_4[i], 3*ratio_4[i], 4*ratio_4[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq4_4 = np.append(time_eq4_4, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_4 = np.append(act_ratio_4, Urm)

N = 5
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio_5 = sc.linspace(0.9,1.1,11)
time_eq5_5 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(ratio_5)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq5_5 = np.append(time_eq5_5, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_5 = np.append(act_ratio_5, Urm)

# %%
act_ratio2 = np.delete(act_ratio2, int((len(act_ratio2)-1)/2))
time_eq2 = np.delete(time_eq2, int((len(time_eq2)-1)/2))
time_eq3_3 = np.delete(time_eq3_3, int((len(time_eq3_3)-1)/2))
time_eq4_4 = np.delete(time_eq4_4, int((len(time_eq4_4)-1)/2))
time_eq5_5 = np.delete(time_eq5_5, int((len(time_eq5_5)-1)/2))

act_ratio = np.delete(act_ratio, int((len(act_ratio)-1)/2))
time_eq = np.delete(time_eq, int((len(time_eq)-1)/2))
time_eq_3 = np.delete(time_eq_3, int((len(time_eq_3)-1)/2))
time_eq_4 = np.delete(time_eq_4, int((len(time_eq_4)-1)/2))
time_eq_5 = np.delete(time_eq_5, int((len(time_eq_5)-1)/2))

# %% [markdown]
# ##### Plots

# %%
plt.plot(act_ratio2, time_eq2,'ko', markersize=4)
plt.plot(act_ratio2, time_eq3_3,'bo', markersize=4)
plt.plot(act_ratio2, time_eq4_4,'go', markersize=4)
plt.plot(act_ratio2, time_eq5_5,'ro', markersize=4)
plt.grid
plt.title('Type 1 - Increasing total bacteria mass in system with sp number')
plt.xlabel('Metabolic Ratio (U1/Rm1 : U2/Rm2)')
plt.ylabel('Timesteps to monodominance')
plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='blue', lw=2),
            Line2D([0], [0], color='green', lw=2), Line2D([0], [0], color='red', lw=2)],
           ['2 sp', '3 sp', '4 sp', '5 sp'])
plt.show()


plt.plot(act_ratio, time_eq,'ko', markersize=4)
plt.plot(act_ratio, time_eq_3,'bo', markersize=4)
plt.plot(act_ratio, time_eq_4,'go', markersize=4)
plt.plot(act_ratio, time_eq_5,'ro', markersize=4)
plt.grid
plt.title('Type 1 - Same total bacteria mass in system')
plt.xlabel('Metabolic Ratio (U1/Rm1 : U2/Rm2)')
plt.ylabel('Timesteps to monodominance')
plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='blue', lw=2),
           Line2D([0], [0], color='green', lw=2), Line2D([0], [0], color='red', lw=2)],
           ['2 sp', '3 sp', '4 sp', '5 sp'])
plt.show()


all_time = np.array([time_eq[4], time_eq_3[4], time_eq_4[4], time_eq_5[4]])
species = np.array([2,3,4,5])
plt.plot(species, all_time,'ro', markersize=4)
all_time2 = np.array([time_eq2[4], time_eq3_3[4], time_eq4_4[4], time_eq5_5[4]])
plt.plot(species, all_time2,'ko', markersize=4)
plt.grid
plt.title('Type 1 - Metabolic ratio 1:2,3,4,5 = 0.98')
plt.xlabel('Number of species')
plt.ylabel('Timesteps to monodominance')
plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='red', lw=2)],
           ['Increasing biomass with sp #', 'Same biomass'])

plt.show()

# %% [markdown]
# #### Type II
# ##### Code

# %%
#### Same bacteria mass in system

# Set up parameters

# U = 10, 20, 30
import Vector_Testing_model as vtm
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc
import statistics as stat

typ = 2
K = 500

t_fin = 1000
k = 0.0000862
Tref = 273.15 # 0 degrees C
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_rm = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
T = 273.15 + 20
Ea_U = np.concatenate([np.repeat(0.6,N)])
Ea_R = np.concatenate([np.repeat(0.9, N)])
Ea_D = np.repeat(3.5,N) # Deactivation energy
t = sc.linspace(0,t_fin-1,t_fin)

N = 2
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio = sc.linspace(0.9,1.1,11)
time_eq = np.array([])
act_ratio = np.array([])
Urm = np.array([])

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq = np.append(time_eq, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio = np.append(act_ratio, Urm)

N = 3
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio_3 = sc.linspace(0.9,1.1,11)
time_eq_3 = np.array([])
act_ratio_3 = np.array([])
Urm = np.array([])

for i in range(len(ratio_3)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_3[i], 3*ratio_3[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_3 = np.append(time_eq_3, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_3 = np.append(act_ratio_3, Urm)

N = 4
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio_4 = sc.linspace(0.9,1.1,11)
time_eq_4 = np.array([])
act_ratio_4 = np.array([])
Urm = np.array([])

for i in range(len(ratio_4)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_4[i], 3*ratio_4[i], 4*ratio_4[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_4 = np.append(time_eq_4, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_4 = np.append(act_ratio_4, Urm)

N = 5
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio_5 = sc.linspace(0.9,1.1,11)
time_eq_5 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(ratio_5)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_5 = np.append(time_eq_5, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_5 = np.append(act_ratio_5, Urm)

# %%
#### Increasing biomass with increasing species

import Vector_Testing_model as vtm
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc
import statistics as stat
# Set up parameters

typ = 2
N=2
# U = 10, 20, 30
t_fin = 1000
k = 0.0000862
Tref = 273.15 # 0 degrees C
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_rm = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
T = 273.15 + 20
Ea_U = np.concatenate([np.repeat(0.6,N)])
Ea_R = np.concatenate([np.repeat(0.9, N)])
Ea_D = np.repeat(3.5,N) # Deactivation energy
t = sc.linspace(0,t_fin-1,t_fin)
K=1

N = 2
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio = sc.linspace(0.9,1.1,11)
time_eq2 = np.array([])
act_ratio2 = np.array([])
Urm = np.array([])

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq2 = np.append(time_eq2, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio2 = np.append(act_ratio2, Urm)

N = 3
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio_3 = sc.linspace(0.9,1.1,11)
time_eq3_3 = np.array([])
act_ratio_3 = np.array([])
Urm = np.array([])

for i in range(len(ratio_3)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_3[i], 3*ratio_3[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq3_3 = np.append(time_eq3_3, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_3 = np.append(act_ratio_3, Urm)

N = 4
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio_4 = sc.linspace(0.9,1.1,11)
time_eq4_4 = np.array([])
act_ratio_4 = np.array([])
Urm = np.array([])

for i in range(len(ratio_4)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_4[i], 3*ratio_4[i], 4*ratio_4[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq4_4 = np.append(time_eq4_4, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_4 = np.append(act_ratio_4, Urm)

N = 5
M = 1
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
ratio_5 = sc.linspace(0.9,1.1,11)
time_eq5_5 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(ratio_5)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k, K, typ)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq5_5 = np.append(time_eq5_5, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    print(U/Rm)
    act_ratio_5 = np.append(act_ratio_5, Urm)
# Out:
# [10.         11.11111111 11.11111111 11.11111111 11.11111111]
# [10.         10.86956522 10.86956522 10.86956522 10.86956522]
# [10.         10.63829787 10.63829787 10.63829787 10.63829787]
# [10.         10.41666667 10.41666667 10.41666667 10.41666667]
# [10.         10.20408163 10.20408163 10.20408163 10.20408163]
# [10. 10. 10. 10. 10.]
# [10.          9.80392157  9.80392157  9.80392157  9.80392157]
# [10.          9.61538462  9.61538462  9.61538462  9.61538462]
# [10.          9.43396226  9.43396226  9.43396226  9.43396226]
# [10.          9.25925926  9.25925926  9.25925926  9.25925926]
# [10.          9.09090909  9.09090909  9.09090909  9.09090909]

# %%
act_ratio2 = np.delete(act_ratio2, int((len(act_ratio2)-1)/2))
time_eq2 = np.delete(time_eq2, int((len(time_eq2)-1)/2))
time_eq3_3 = np.delete(time_eq3_3, int((len(time_eq3_3)-1)/2))
time_eq4_4 = np.delete(time_eq4_4, int((len(time_eq4_4)-1)/2))
time_eq5_5 = np.delete(time_eq5_5, int((len(time_eq5_5)-1)/2))

act_ratio = np.delete(act_ratio, int((len(act_ratio)-1)/2))
time_eq = np.delete(time_eq, int((len(time_eq)-1)/2))
time_eq_3 = np.delete(time_eq_3, int((len(time_eq_3)-1)/2))
time_eq_4 = np.delete(time_eq_4, int((len(time_eq_4)-1)/2))
time_eq_5 = np.delete(time_eq_5, int((len(time_eq_5)-1)/2))

# %% [markdown]
# ##### Plots

# %%
plt.plot(act_ratio2, time_eq2,'ko', markersize=4)
plt.plot(act_ratio2, time_eq3_3,'bo', markersize=4)
plt.plot(act_ratio2, time_eq4_4,'go', markersize=4)
plt.plot(act_ratio2, time_eq5_5,'ro', markersize=4)
plt.grid
plt.title('Type II - Increasing total bacteria mass in system with sp number')
plt.xlabel('Metabolic Ratio (U1/Rm1 : U2/Rm2)')
plt.ylabel('Timesteps to monodominance')
plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='blue', lw=2),
            Line2D([0], [0], color='green', lw=2), Line2D([0], [0], color='red', lw=2)],
           ['2 sp', '3 sp', '4 sp', '5 sp'])
plt.show()


plt.plot(act_ratio, time_eq,'ko', markersize=4)
plt.plot(act_ratio, time_eq_3,'bo', markersize=4)
plt.plot(act_ratio, time_eq_4,'go', markersize=4)
plt.plot(act_ratio, time_eq_5,'ro', markersize=4)
plt.grid
plt.title('Type II - Same total bacteria mass in system')
plt.xlabel('Metabolic Ratio (U1/Rm1 : U2/Rm2)')
plt.ylabel('Timesteps to monodominance')
plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='blue', lw=2),
           Line2D([0], [0], color='green', lw=2), Line2D([0], [0], color='red', lw=2)],
           ['2 sp', '3 sp', '4 sp', '5 sp'])
plt.show()


all_time = np.array([time_eq[4], time_eq_3[4], time_eq_4[4], time_eq_5[4]])
species = np.array([2,3,4,5])
plt.plot(species, all_time,'ro', markersize=4)
all_time2 = np.array([time_eq2[4], time_eq3_3[4], time_eq4_4[4], time_eq5_5[4]])
plt.plot(species, all_time2,'ko', markersize=4)
plt.grid
plt.title('Type II - Metabolic ratio 1:2,3,4,5 = 0.98')
plt.xlabel('Number of species')
plt.ylabel('Timesteps to monodominance')
plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='red', lw=2)],
           ['Increasing biomass with sp #', 'Same biomass'])

plt.show()

# %% [markdown]
# ### 2 - 5 species system, 2-5 different functional groups

# %%
N = 5
M = 1
x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio_5 = sc.linspace(0.9,1.1,11)
time_eq_5 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(ratio_5)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    Rm = np.array([1,2.05*ratio_5[i], 3.05*ratio_5[i], 4.05*ratio_5[i], 5.05*ratio_5[i]])
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_5 = np.append(time_eq_5, len(np.unique(pops, axis=0)))
    U.shape = N
    Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    act_ratio_5 = np.append(act_ratio_5, Urm)

print(U)
print(Rm)
print(U/Rm)
print(((U[0]/Rm[0]) - (U[1:5]/Rm[1:5])))
print(stat.mean((U[0]/Rm[0]) - (U[1:5]/Rm[1:5])))
#print(act_ratio_5)

time_eq_5 = np.delete(time_eq_5, int((len(time_eq_5)-1)/2))
act_ratio_5 = np.delete(act_ratio_5, int((len(act_ratio_5)-1)/2))



#plt.plot(act_ratio, time_eq,'ko', markersize=4)
#plt.plot(act_ratio, time_eq_3,'bo', markersize=4)
#plt.plot(act_ratio, time_eq_4,'go', markersize=4)
#plt.plot(act_ratio_5, time_eq_5,'ro', markersize=4)
#plt.grid
#plt.title('Same total bacteria mass in system')
#plt.xlabel('Metabolic Ratio (U1/Rm1 : U2/Rm2)')
#plt.ylabel('Timesteps to monodominance')
#plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='blue', lw=2),
#           Line2D([0], [0], color='green', lw=2), Line2D([0], [0], color='red', lw=2)],
#           ['2 sp', '3 sp', '4 sp', '5 sp'])
#plt.show()
# Out:
# [10. 20. 30. 40. 50.]
# [1.    2.255 3.355 4.455 5.555]
# [10.          8.8691796   8.94187779  8.97867565  9.00090009]
# [1.1308204  1.05812221 1.02132435 0.99909991]
# 1.05234171735624

# %%
from numpy.random import rand

N = 5
M = 1

y = np.array([0.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
y2 = np.array([9.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
ran = rand(N-1)
#print(ran)
#ran_tmp = ran/sum(ran)

t1 = (y2[0] * (N-1)) / (U[0] * (N-1))
#print(t)
ran_tmp = ran/sum(ran)*(t1*-1)
#print(ran_tmp)

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
t_fin = 5000 # 20,000 timesteps sees all reached equilibrium
t = sc.linspace(0,t_fin-1,t_fin)

ratio_5 = sc.linspace(0.9,1.1,11)
time_eq_5 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(y)):
    # 0.9
    ran_test = ran_tmp * y[i] * U[0]
    #print(10 - ran_test)

    rm_arr = np.array([1])

    for j in range(N-1):
        rm_tmp = (U[j+1]/((U[0]/Rm[0]) - ran_test[j]))
        rm_arr = np.append(rm_arr, rm_tmp)
    
    #print(np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))

        # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    Rm = rm_arr
    #print(Rm)
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_5 = np.append(time_eq_5, len(np.unique(pops, axis=0)))
    #U.shape = N
    #Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    #act_ratio_5 = np.append(act_ratio_5, np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))

print(pops[t_fin-1,:])
# Out:
# [-0.      -0.       0.48564  0.       0.       0.1144 ]

# %%
from numpy.random import rand

N = 4
M = 1

y = np.array([0.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
y2 = np.array([9.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
ran = rand(N-1)
#print(ran)
#ran_tmp = ran/sum(ran)

t1 = (y2[0] * (N-1)) / (U[0] * (N-1))
#print(t)
ran_tmp = ran/sum(ran)*(t1*-1)
#print(ran_tmp)

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
t_fin = 5000 # 20,000 timesteps sees all reached equilibrium
t = sc.linspace(0,t_fin-1,t_fin)

ratio_5 = sc.linspace(0.9,1.1,11)
time_eq_4 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(y)):
    # 0.9
    ran_test = ran_tmp * y[i] * U[0]
    #print(10 - ran_test)

    rm_arr = np.array([1])

    for j in range(N-1):
        rm_tmp = (U[j+1]/((U[0]/Rm[0]) - ran_test[j]))
        rm_arr = np.append(rm_arr, rm_tmp)
    
    #print(np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))

        # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    Rm = rm_arr
    #print(Rm)
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_4 = np.append(time_eq_4, len(np.unique(pops, axis=0)))
    #U.shape = N
    #Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    #act_ratio_5 = np.append(act_ratio_5, np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))

# %%
from numpy.random import rand

N = 3
M = 1

y = np.array([0.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
y2 = np.array([9.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
ran = rand(N-1)
#print(ran)
#ran_tmp = ran/sum(ran)

t1 = (y2[0] * (N-1)) / (U[0] * (N-1))
#print(t)
ran_tmp = ran/sum(ran)*(t1*-1)
#print(ran_tmp)

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
t_fin = 5000 # 20,000 timesteps sees all reached equilibrium
t = sc.linspace(0,t_fin-1,t_fin)

ratio_5 = sc.linspace(0.9,1.1,11)
time_eq_3 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(y)):
    # 0.9
    ran_test = ran_tmp * y[i] * U[0]
    #print(10 - ran_test)

    rm_arr = np.array([1])

    for j in range(N-1):
        rm_tmp = (U[j+1]/((U[0]/Rm[0]) - ran_test[j]))
        rm_arr = np.append(rm_arr, rm_tmp)
    
    #print(np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))

        # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    Rm = rm_arr
    #print(Rm)
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_3 = np.append(time_eq_3, len(np.unique(pops, axis=0)))
    #U.shape = N
    #Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    #act_ratio_5 = np.append(act_ratio_5, np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))

# %%
from numpy.random import rand

N = 2
M = 1

y = np.array([0.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
y2 = np.array([9.9, 0.95, 0.98, 0.99, 1.01, 1.02, 1.05, 1.1])
ran = rand(N-1)
#print(ran)
#ran_tmp = ran/sum(ran)

t1 = (y2[0] * (N-1)) / (U[0] * (N-1))
#print(t)
ran_tmp = ran/sum(ran)*(t1*-1)
#print(ran_tmp)

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
t_fin = 5000 # 20,000 timesteps sees all reached equilibrium
t = sc.linspace(0,t_fin-1,t_fin)

ratio_5 = sc.linspace(0.9,1.1,11)
time_eq_2 = np.array([])
act_ratio_5 = np.array([])
Urm = np.array([])

for i in range(len(y)):
    # 0.9
    ran_test = ran_tmp * y[i] * U[0]
    #print(10 - ran_test)

    rm_arr = np.array([1])

    for j in range(N-1):
        rm_tmp = (U[j+1]/((U[0]/Rm[0]) - ran_test[j]))
        rm_arr = np.append(rm_arr, rm_tmp)
    
    #print(np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))

        # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio_5[i], 3*ratio_5[i], 4*ratio_5[i], 5*ratio_5[i]])
    Rm = rm_arr
    #print(Rm)
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_2 = np.append(time_eq_2, len(np.unique(pops, axis=0)))
    #U.shape = N
    #Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    #act_ratio_5 = np.append(act_ratio_5, np.round(stat.mean(10 - (U[1:5]/rm_arr)),3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-34dd6e61ef3b> in <module>
#       1 from numpy.random import rand
# ----> 2 set.seed(123)
#       3
#       4 N = 2
#       5 M = 1
#
# AttributeError: type object 'set' has no attribute 'seed'

# %%
N = 5
M = 1

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
ratio = np.array([1.01,  1.5, 2])
time_eq_5 = np.array([])
sd_ratio_5 = np.array([])
#Urm = np.array([])
t_fin = 20000 # 20,000 timesteps sees all reached equilibrium
t = sc.linspace(0,t_fin-1,t_fin)

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio[i]])
    Rm_temp = sc.linspace(1,N, N)
    Rm = Rm_temp * (np.random.normal(ratio[i], 0.1,N)) # mean = 1
    
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_5 = np.append(time_eq_5, len(np.unique(pops, axis=0)))
    U.shape = N
    #Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    sd_ratio_5 = np.append(sd_ratio_5, ratio/1)
    print(stat.mean((U/Rm)))
#print(time_eq_5)

N = 4
M = 1

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
time_eq_4 = np.array([])
sd_ratio_4 = np.array([])
#Urm = np.array([])
#t_fin = 5000 # 20,000 timesteps sees all reached equilibrium
#t = sc.linspace(0,t_fin-1,t_fin)

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio[i]])
    Rm_temp = sc.linspace(1,N, N)
    Rm = Rm_temp * (np.random.normal(ratio[i], 0.1,N)) # mean = 1
    
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_4 = np.append(time_eq_4, len(np.unique(pops, axis=0)))
    U.shape = N
    #Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    sd_ratio_4 = np.append(sd_ratio_4, ratio/1)
    print(stat.mean((U/Rm)))
#print(time_eq_4)

N =3 
M = 1

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
time_eq_3 = np.array([])
sd_ratio_3 = np.array([])
#Urm = np.array([])
#t_fin = 5000 # 20,000 timesteps sees all reached equilibrium
#t = sc.linspace(0,t_fin-1,t_fin)

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio[i]])
    Rm_temp = sc.linspace(1,N, N)
    Rm = Rm_temp * (np.random.normal(ratio[i], 0.1,N)) # mean = 1
    
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_3 = np.append(time_eq_3, len(np.unique(pops, axis=0)))
    U.shape = N
    #Urm = (U[0]/Rm[0])/(U[1]/Rm[1])
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    print(stat.mean((U/Rm)))
    sd_ratio_3 = np.append(sd_ratio_3, ratio/1)
#print(time_eq_3)

N = 2
M = 1

x0_temp = 0.2/N
x0 = np.concatenate((sc.full([N], (x0_temp)),sc.full([M], (1.0))))
time_eq_2 = np.array([])
sd_ratio_2 = np.array([])
#Urm = np.array([])
#t_fin = 5000 # 20,000 timesteps sees all reached equilibrium
#t = sc.linspace(0,t_fin-1,t_fin)

for i in range(len(ratio)): 
    # Set up model
    U = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[0]
    Rg = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[2] # l + Rg must be less than 1
    l = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[3]
    p = vtm.params(N, M, T, k, Tref, T_pk, B_g, B_rm,Ma, Ea_U, Ea_R, Ea_D)[4]
    l_sum = np.sum(l, axis=1)
    #Rm = np.array([1,2*ratio[i]])
    Rm_temp = sc.linspace(1,N, N)
    Rm = Rm_temp * (np.random.normal(ratio[i], 0.1,N)) # mean = 1
    
    # Run model
    pars = (U, Rm, Rg, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_rm, B_g, Ma, k)
    pops = odeint(vtm.metabolic_model, y0=x0, t=t, args = (pars))
    pops = np.round(pops, 5)
    time_eq_2 = np.append(time_eq_2, len(np.unique(pops, axis=0)))
    U.shape = N
    #print((U[0]/Rm[0])/(U[1]/Rm[1]))
    print(stat.mean((U/Rm)))
    #print(U/Rm)
    #print(stat.mean((U/Rm)/(U/Rm)))
    sd_ratio_2 = np.append(sd_ratio_2, ratio/1)

#print(time_eq_2)
# Out:
# 9.433134836388074
# 6.601258961577555
# 4.866496974587887
# 9.18338321417304
# 6.566364007119896
# 5.043075505227835
# 9.986717482223279
# 7.048638893792839
# 4.96251257788277
# 11.28460272315758
# 6.569715664627647
# 4.711302925851006

# %% [markdown]
# #### Plots

# %%
import matplotlib.pylab as plt

plt.plot(ratio, time_eq_2,'ko', markersize=4)
plt.plot(ratio, time_eq_3,'bo', markersize=4)
plt.plot(ratio, time_eq_4,'go', markersize=4)
plt.plot(ratio, time_eq_5,'ro', markersize=4)
plt.grid
#plt.title('Increasing total bacteria mass in system with sp number')
plt.xlabel('Mean of U/R distribution')
plt.ylabel('Timesteps to monodominance')
plt.legend([Line2D([0], [0], color='black', lw=2), Line2D([0], [0], color='blue', lw=2),
           Line2D([0], [0], color='green', lw=2), Line2D([0], [0], color='red', lw=2)],
           ['2 sp', '3 sp', '4 sp', '5 sp'])
plt.show()

# %% [markdown]
# ### Non-dimensionalisation
#
# To reduce parameters needed making it simpler to find a realistic time to assembly under different competiting metabolic ratio scenarios.
#
# 1. Select constants ($C_0$, $S_0$, $t_0$) to divide $C$, $S$ and $t$ by respectively:
#
# \begin{equation}
# \beta = C / C_0
# \end{equation}
#
# \begin{equation}
# \eta = S / S_0
# \end{equation}
#
# \begin{equation}
# \tau = t / t_0
# \end{equation}
#
# 2. This means:
#
# \begin{equation}
# \frac{dC}{dt} = \frac{C_0d\beta}{t_0d\tau}
# \end{equation}
#
# \begin{equation}
# \frac{dS}{dt} = \frac{S_0d\eta}{t_0d\tau}
# \end{equation}
#
# 3. Inserting these into the model equations results in
#
# \begin{equation}
# \frac{C_0d\beta}{t_0d\tau} = C_0\beta(S_0\eta U(1-l) - R)
# \end{equation}
#
# \begin{equation}
# \frac{S_0d\eta}{t_0d\tau} = \rho - S_0\eta C_0\beta U(1-l)
# \end{equation}
#
# which simplifies to:
#
# \begin{equation}
# \frac{d\beta}{d\tau} = t_0\beta(S_0\eta U(1-l) - R)
# \end{equation}
#
# \begin{equation}
# \frac{d\eta}{d\tau} = t_0(\frac{\rho}{S_0} - \eta C_0\beta U(1-l))
# \end{equation}
#
# 4. Find values for $C_0$, $S_0$ and $t_0$...

# %% [markdown]
# ## Summary
#
# ### Summary to this point
# - No competition for resources, no extinction, lowest $R_m$ wins. This overcomes any differences in $U$/$R_m$.
# - Competition for resources, no extinction if $U_1$/$R_{m1}$ = $U_2$/$R_{m2}$, but the one with the highest $U$ (or $R_m$) wins. Occurs for 2:1 or 3:1 system (species:resources).
# - Competition for resources, extinction if $U_1$/$R_{m1}$ != $U_2$/$R_{m2}$. The bacteria with the highest $U$/$R_{m}$ wins (as also in Chesson 2000 - equalising mechanism) as has highest uptake relative to respiration loss. Highest $U$/$R_{m}$ typically occurs in the species with the lowest $R_m$.
#
# ### Next steps
# - Analytically prove summary points above (plot $Rm$, $U$, $Ea$ against bacteria biomass ($C1$, $C2$ etc.)).
# - Simulate in large system (Bacteria_vector_model.py), both the competitive and non-competitive scenarios.
#     - Forced $Rm$ to either comply to U/Rm is equal between competitors or to not comply. To find Ea of competitors would need to rearrange Arrhenius equation as setting Rm first.
#     - The actual $U$ and $Rm$ values of the two competitors matters here, one with highest has advantage in the pairing. However in the overall community, those with lower $U$ and $Rm$ have advantage (***show in figure***).
# - Switch off $\rho$ for different resources and explore high/low leakage between resources.
#     - When only first resource has external input ($\rho$), then bacteria feeding off that have higher mass, but still the same rules apply for competition, where those with the higher $U$ and $U$/$Rm$ have advantage.
#     - Lower leakage just lowers the mass of all bacteria.
# - Split the code into different .py files/modules.
#
#
# - Read literature on constraints for co-existence.
#     - Are there models already allowing equalising stability?
#     - What is new in this work:
#         - Does the metabolic ratio constrain/limit community assembly?
#             - Who wins or has the advantage?
#             - Time to equilibrium (closer the metabolic ratio the longer until one becomes extinct).
#         - Metabolic theory and temperature?
#         - Bacteria? Similar to chemostat models but has leakage. Could be phyto too.
#         - $>$ 2 species?
#         - Not an LV model

# %% [markdown]
# ## Plan
#
# ### Model simulations
#
# #### Look at time to equilibrium (i.e. one goes extinct)
# - for competiting pairs (2 sp) with different metabolic ratios
# - for more than 2 sp, i.e. 3, or 5. Does time to equilibrium reduce?
# - Make model non-dimensional
# - Get parameters to calculate a time (hours) for assembly
#
# #### Temperature/metabolism
# - What does different strategies mean for metabolic ratio (i.e. high BO, low Ea vs. low B0 high Ea)
# - At what temperatures (relative to a Topt) will certain strategies have advantage or outcompete others?
# - How does this change as metabolic ratio changes?
#
# ### Plan for potential paper
# - Present and justify model
#     - Adaptation from Marsay (what was motivation)/MacArthur/Chemostat models
#         - From Marsland: 'central goal of microbial community ecology is to understand how variations in diversity, stability and functional structure arise from an interplay of environmental factors such as energy and resource availability and ecological processes such as competition and stochastic colonization'.
#     - To explore impacts of stressors (temperature/pollution) on assembly
#     - Identify big problem in assembly research
# - Describe constraints
#     - Analytical solutions
#     - Metabolic ratio
#         - How found it
#         - Relevance and history (i.e. equalism in stability, Chesson 2000)
#         - Time to equilibrium takes longer closer to 1
#     - Cross-feeding - not really happening here
#     - Supply of external resources
# - Use Biotraits data and other literature values to parameterise model.
# - Present model results
#     - Situations in which different analytical solutions are met (i.e. metabolic ratio = 1 or != 1)
#     - For species of different temperature approaches, i.e. specialist (high Ea, low B0) vs .generalist (low Ea, high Bo), and how these two strategies compare competiting at different temperatures
#     - For more than 2 species competing for a resource
#     - Calculate realistic time to assembly using extensive parameter search
# - Discussion
#     - Relevance to current understanding of community assembly
#     - Compare our model to other similar models and suggest novel uses
#     - Discuss results of specialist vs generalist competing to assemble at different temperatures relative to their Topt
#
# ### Future paper
# - Extensive parameter search and scan
# - Compare model results to competition data
# - Find data to validate model
# - Code
#     - Make user friendly
#     - Modularise as much as possible that is sensible
#     - Set conditions (i.e. only runs if vectors are correct size)
#     - Make work with any number of bacteria or resources
#     - Document for Github

# %% [markdown]
# ------------------------
#
# ------------------------
#
# ------------------------
#
# ------------------------
#
# ------------------------
#
# ------------------------
#
# ------------------------
#
# ------------------------
#
# ------------------------
#
# ------------------------

# %% [markdown]
# ## Analysing the model
#
# ### Incorporating temperature
#
# The solutions for bacteria at equilibrium where the Arrhenius equation is used (i.e. no Tpk):
#
# \begin{equation}
# C = \frac{\rho(1 - Rg - l)}{B_{Rm}M^{-0.25}e^{(-Ea/k)(\frac{1}{T} - \frac{1}{T_{ref}})}
# (1-l)}
# \end{equation}
#
# and for resources are:
#
# <span class="mark">\begin{equation}
# S = \frac{B_{rm}M^{-0.25}e^{(-Ea/k)(\frac{1}{T} - \frac{1}{T_{ref}})}}{B_{u}M^{-0.25}e^{(-Ea/k)(\frac{1}{T} - \frac{1}{T_{ref}})}(1-Rg-l)} =  \frac{B_{rm}}{B_{u}(1-Rg-l)}
# \end{equation}
#
# Resource ($S$) is independant of $Ea$ and individual functional traits aside from $B0$</span>
#
# ### Find all possible equilibria Bacteria masses at different Ea values
#
# Rearranging Equation 11 yields:
#
# \begin{equation}
# Ea = \frac{kln\Bigl(\frac{\rho(1-Rg-l)}{CB_{Rm}M^{-0.25}(1-l)}\Bigl)}{\frac{1}{T} - \frac{1}{T_{ref}}}
# \end{equation}

# %% [markdown]
# - When T = T_pk the difference in R* between different individuals is largest.
# - Groups with lower $Ea$ have competitive advantage
# - The assembly model (below) selects for species with low $Ea$
#
#
# ![alt text](R*_20C.png)
#
# <!--- Plotting bacteria mass against R* for the structured and random preference matrix gives:--->
#
#
# <!--- ![alt text](B_vs_R_struct.png)--->
#
# <!--- ![alt text](B_vs_R_rand1.png)--->
#
# <!--- Where purple = low temperature and yellow = high temperature. Green is T_pk (20 C) which gives highest R* and B.--->
#
#
# <!--- Also, when randomly sharing nutrients do not have same mass of nutrient that their competition (see nutrient (N_num) #8 in table).--->
# <!--- ![alt text](preview_data.png)--->

# %%
k = 0.0000862; Rg = 0; l = 0.4; T = 293.15; Tref = 273.15; Ma = 1; B_rm = 0.1; p=1

C = sc.linspace(0.001,10,100) # Bacteria
Ea = -(k * np.log((p * (1-Rg-l))/ (C * B_rm * Ma**-0.25 * (1-l))))/((1/T)-(1/Tref)) # Ea

from sklearn import linear_model
lm = linear_model.LinearRegression()
model = lm.fit(Ea.reshape(-1,1),np.log(C)) # run linear model

Ea1 = sc.linspace(0,4,100) # predict for plotting, Ea (x values)
C1 = np.exp(lm.intercept_ + (Ea1 * lm.coef_)) # predict for plotting, C (y values)

# Plot
plt.plot(Ea1, C1, 'g-', label = 'Consumers', linewidth=1.7)
plt.grid
plt.ylabel('Bacteria Biomass')
plt.xlabel('Activation Energy')
plt.show()

# %% [markdown]
# ### Expressing size dependancy
#
# It is uncertain whether size would increase fitness/population size in bacteria. This is because a larger size could increase genome increasing growth rate, but could also increase maintenance respiration ($Rm_i$) which would negatively impact on growth rates and population size. Instead of forcing size to have a positive or negative impact on population size both these relationships can be incorporated into the model. As body size increases, $u_{ij}$ will rise, increasing uptake and have a positive impact on population growth. $Rm_i$ will also increase with body size, but this is a loss term from the bacteria consumer so decreases overall population growth. $B$ for $u_{ij}$ (growth, $Bg$) will be higher than for $Rm_i$ (respiration, $Brm$).

# %% [markdown]
# ## Context and possible aim
#
# ### Aim
# Publish a model that can predict which functional groups (> 2, i.e. complex communities) will win/immigrate in novel environmental conditions caused by warming. Show how R* varies with temperature sensitivity (Ea and Tpk)
#
# In this laboratory study [(Jiang & Moran 2004)](https://besjournals.onlinelibrary.wiley.com/doi/full/10.1111/j.0021-8790.2004.00830.x) two cilitates are grown independently at different temperatures they grow without an issue (data not shown). When they grow together at different temperatures one (the specialist, closed points) out-competes the other (the generalist, open points) at intermediate temperatures.
#
# ![alt text](Cilitates.png)
#
# Also see 'Our model system illustrates that horizontal (competition) and vertical (enemy–victim) interactions and dispersal markedly affect the distributions and abundances of species. Because these factors are omnipresent in nature, predicting changes in distribution and abundance under global warming by extrapolation of the climate envelope may lead to serious errors' from [(Davis et al 1998)](https://www.nature.com/articles/35842).
#
# And 'The species interaction mechanism both helps to explain why many treelines have not advanced in response to climatic warming and highlights that predictions of treeline shifts based solely on climate may be misleading, because interspecific interactions can temper effects of climatic change'. [(Liang et al 2016)](https://www.pnas.org/content/113/16/4380.short)

# %% [markdown]
# #### Model simulations
#
# Aims are to determine equilibria values of bacteria ($C$) when (a) $Ea$ for all bacteria is the same and (b) $Ea$ is different for both bacteria, under different scenarios:
# 1. Bacteria are not competiting for resources, i.e. M = N ($\rho$, external input, is set to 1 for all resources)
# 2. Bacteria are competiting for resources, i.e. M = N/2 ($\rho$ is set to 1 for all resources)
# 3. $\rho$ is set to 1 for $\rho_0$ (the first resource) and to 0 for the rest for M = N (i.e. cross-feeding becomes important)
# 4. $\rho$ is 0 for all resources for M = N
#
# $Ea$ = 0.6 and 1.0
# $Ea_D$ = 3.5
# $T$ = 293.15
# $Tref$ = 273.15
# $k$ = 0.0000862
# $Ma$ = 1
# $U$ = 2.8 and 9.1
# $Rm$ = 0.56 and 1.8
# $Rg$ = 0
# $l$ = 0.4
# $B_{rm}$ = 0.1
# $B_g$ = 0.5
# $\rho$ = 1
#
# Only for Scenarios 1a & b does the model result match the analytical solution. Note in scenario a) $Ea$ = 0.6 eV for both bacteria and in scenario b) $Ea$ = 0.6 eV for C1 and 1.0 eV for C2. Below C1 and C2 refer to bacteria and S1 and S2 to resources:
#
# |Scenarios | C1 | C2 | S1 | S2 | Notes|
# |---|---|---|---|---|---|
# |1a | 1.76 | 1.76 | 0.33 | 0.33 | C and S same as analytical solution (M = N, $\rho$ = c(1,1), Ea = c(0.6,0.6)|
# |1b | 1.76 | 0.55 | 0.33 | 0.33 | C and S Same as analytical solution (M = N,$\rho$ = c(1,1), Ea = c(0.6,1.0)|
# |2a | 0.88 | 0.88 | 0.33 | NA | C1 and C2 are half of analytical solution, i.e. 1.76/2 = 0.88 (M = N/2, $\rho$ = c(1), Ea = c(0.6,0.6)|
# |2b | 0.17 | 0.50 | 0.33 | NA | C1 and C2 are different to analytical solution and here the higher $Ea$ (C2) 'wins'  (M = N/2, $\rho$ = c(1), Ea = c(0.6,1.0)|
# |3a | 1.26 | 0.50 | 0.33 | 0.33 | C1 = 72 % and C2 = 28 % of analytical solution, the C that has access to a resource with an external supply wins, S1 and S2 same as solution (M = N, $\rho$ = c(1,0), Ea = c(0.6,0.6)|
# |3b | 1.26 | 0.16 | 0.33 | 0.44 | Different to analytical solution, the C with a resource with an external supply 'wins' (M = N, $\rho$ = c(1,0), Ea = c(0.6,1.0)|
# |4a | 0.00 | 0.00 | 0.04 | 0.04 | Analytical solution predicts C correctly but not S (M = N, $\rho$ = c(0,0), Ea = c(0.6,0.6)|
# |4b | 0.00 | 0.00 | 0.09 | 0.15 | Analytical solution predicts C correctly but not S (M = N, $\rho$ = c(0,0), Ea = c(0.6,1.0)|
#
#
# ##### Conclusions of model simulation equlibria
# * When the bacteria do not compete for resources (i.e. N = M as per Scenario 1a & b) the analytical solutions of all C and S match the model. As per the vectorised simulations (results of Jan/Feb 2020) the lowest $Ea$ value (0.6 eV comapred to 1.0 eV) 'wins' with a higher bacterial mass.
# * When the bacteria do not compete (N = M) and have the same $Ea$ (Scenario 2a) the equilibria bacterial mass can be found by dividing the analystical solution by 2. This is constant across all $Eas$. When the $Ea$ are different, there is no obvious connection between the simulated and analytical equilibria. Further, the highest $Ea$ has the highest bacteria mass which contradicts all previous work and runs of the vectorised model.
# * When bacteria do not compete but only one has access to an external resource input (Scenario 3a) then the bacterial mass is 72 \% of the analytical solution when $\rho$ = 1 and 28 % of the solution when $\rho$ = 0. This is when the $Ea$ are the same. When the $Ea$ are different (Scenario 3b), the one with the resource input wins and as of yet there is no relationship between the bacteria with 0 external input of resources and the analytical solution but could be related to the relative difference in $Ea$.
# * When there are no external resource inputs all bacteria die as predicted by the analytical solution but the solution cannot predict the resource mass. It is unlikely this scenario (Scenario 4a or b) will be relevant in nature.
#
# **When not competiting for resources the lowest Ea wins, when competiting for resources the highest Ea wins**
#
# **When only one resources has an external input then that resource wins, although others with a higher $Ea$ will do well too. Further down the chain the nutrients become depleted - is this representative of a natural system?**
#
# **Perhaps to introduce cross-feeding we make different functional groups which have one external nutrient and they cross feed amongst themselves - a chain is not realistic of nature**
#
# **Unless some resources have $\rho$ = 0, then there is no extinction**

# %% [markdown]
# # Implication of competition on ecological response to warming  <a class="tocSkip">

# %%
import Bacteria_vector_modular as bvm
import parameters as par
import model_func as mod
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
from scipy.integrate import odeint
import numpy as np
import scipy as sc

# Set up parameters
N = 10
M = 5
t_fin = 100
k = 0.0000862
Tref = 273.15 # 0 degrees C
pk = 20 # 
T_pk = Tref + pk
B_g = 0.5 # B0 for growth (uptake)
B_r = 0.1 # B0 for mainternace respirations
Ma = 1 # Mass
T = 273.15 + 20
Ea_U = np.concatenate([np.repeat(0.6,N/2), np.repeat(0.9,N/2)])
Ea_R = np.concatenate([np.repeat(0.7,N/2), np.repeat(0.5,N/2)])
Ea_D = np.repeat(3.5,N) # Deactivation energy
t_n = 21 # number of temperatures 
t_n_output = (t_n * N) + N # number of rows in output array
t_fin = 100
t = sc.linspace(0,t_fin-1,t_fin)
ass = 1
Meta_ratio = np.array([1, 1.1, 1, 0.9, 1])
U = par.params(N, M, T, k, Tref, T_pk, B_g, B_r,Ma, Ea_U, Ea_R, Ea_D, Meta_ratio)[0]
R = par.params(N, M, T, k, Tref, T_pk, B_g, B_r,Ma, Ea_U, Ea_R, Ea_D, Meta_ratio)[1] 
l = par.params(N, M, T, k, Tref, T_pk, B_g, B_r,Ma, Ea_U, Ea_R, Ea_D, Meta_ratio)[2]
p = par.params(N, M, T, k, Tref, T_pk, B_g, B_r,Ma, Ea_U, Ea_R, Ea_D, Meta_ratio)[3]
l_sum = np.sum(l, axis=1)
x0 = np.concatenate((sc.full([N], (0.1)),sc.full([M], (1.0))))
pars = (U, R, l, p, l_sum, Ea_U, Ea_R, Ea_D, N, M, T, Tref, B_r, B_g, Ma, k, Meta_ratio, ass)

# Run model
pops = odeint(mod.metabolic_model, y0=x0, t=t, args = pars)
pops = np.round(pops, 3)
#print('C1 = ' + str(pops[t_fin-1,0]), ', C2 = ' + str(pops[t_fin-1,1]), ', S1 = ' + str(pops[t_fin-1,2])) #, ', S2 = ' + str(pops[t_fin-1,3]))
#print('U/Rm = ' + str(np.round(np.diag(U/Rm),3)))


#### Plot output ####
t_plot = sc.linspace(0,100,100)
plt.plot(t, pops[:,0:N], 'g-', label = 'Consumers', linewidth=0.7)
plt.plot(t, pops[:,N:N+M], 'b-', label = 'Resources', linewidth=0.7)
plt.grid
plt.ylabel('Population density')
plt.xlabel('Time')
plt.title('Bacteria-Nutrients population dynamics')
plt.legend([Line2D([0], [0], color='green', lw=2), Line2D([0], [0], color='blue', lw=2)], ['Bacteria', 'Nutrients'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b9f35b9af308> in <module>
#       9 from importlib import reload
#      10
# ---> 11 reload(model_func)
#      12
#      13 # Set up parameters
#
# NameError: name 'model_func' is not defined
